# %% [markdown]
# ## найти все апи-схемы в нашей системе и принудительно обновить

# %%
import requests
import time
import json

# —————————————————————————
# Настройки
TOKEN = "gb_api_vVVR78hJXh8dkcFDRtgn9LBHtFTQUmWAkQDdXe8q"
ORG_ID = "isNk5xPnJebTWJa4JCg5"

BASE_URL = "https://api.gitbook.com/v1"

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json",
    "Accept": "application/json",
}

# —————————————————————————
def list_openapi_specs():
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi?limit=1000"
    resp = requests.get(url, headers=HEADERS)
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    resp.raise_for_status()
    return resp.json().get("items", [])

def update_spec(spec_slug, source_url):
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi/{spec_slug}"
    body = {
        "source": {
            "url": source_url
        }
    }
    resp = requests.put(url, json=body, headers=HEADERS)
    resp.raise_for_status()
    return resp.json()

def main():
    specs = list_openapi_specs()

    total = len(specs)
    updated = 0
    failed = 0
    skipped = 0

    print(f"Found {total} OpenAPI specs\n")

    for spec in specs:
        slug = spec.get("slug")
        source_url = spec.get("sourceURL")

        if not slug or not source_url:
            skipped += 1
            print(f"Skipped: missing slug or sourceURL → {spec.get('id', 'unknown')}")
            continue

        print(f"Updating: {slug}")

        try:
            update_spec(slug, source_url)
            updated += 1
            print(f" ✓ Updated")
        except Exception as e:
            failed += 1
            print(f" ✗ Failed: {e}")

        # защита от rate-limit
        time.sleep(0.2)

    # —————————————————————————
    print("\n====== SUMMARY ======")
    print(f"Total specs      : {total}")
    print(f"Updated          : {updated}")
    print(f"Failed updates   : {failed}")
    print(f"Skipped          : {skipped}")
    print("=====================")


if __name__ == "__main__":
    main()
# Out:
# {
#   "items": [
#     {
#       "object": "openapi-spec",
#       "id": "oas_4yY0m",
#       "createdAt": "2025-12-24T03:28:49.000Z",
#       "updatedAt": "2025-12-24T03:28:49.000Z",
#       "slug": "m2-1",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/MiniMax/m2-1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:28:52.632Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_GTmSM",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/m2-1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/m2-1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_ENyO4",
#       "createdAt": "2025-12-24T03:23:23.000Z",
#       "updatedAt": "2025-12-24T03:23:23.000Z",
#       "slug": "minimax-m2-1",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/MiniMax/m2-1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:23:27.979Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_k08J4",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/minimax-m2-1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/minimax-m2-1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_xTH2q",
#       "createdAt": "2025-12-24T03:20:56.000Z",
#       "updatedAt": "2025-12-24T03:20:56.000Z",
#       "slug": "glm-4-7",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Zhipu/glm-4.7.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:21:00.615Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_u5OSV",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/glm-4-7",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/glm-4-7"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_V9akS",
#       "createdAt": "2025-12-24T02:40:48.000Z",
#       "updatedAt": "2025-12-24T02:40:48.000Z",
#       "slug": "video-o1-reference-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-o1-reference-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T08:40:51.907Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_guC1Z",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-o1-reference-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-o1-reference-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_hLL95",
#       "createdAt": "2025-12-24T01:29:34.000Z",
#       "updatedAt": "2025-12-24T01:29:34.000Z",
#       "slug": "video-01",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/MiniMax/video-01.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T07:29:37.330Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_FbdoD",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-01",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-01"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_bFFVQ",
#       "createdAt": "2025-12-24T01:21:15.000Z",
#       "updatedAt": "2025-12-24T01:21:15.000Z",
#       "slug": "video-01-live2d",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/MiniMax/video-01-live2d.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T07:21:18.754Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/requestBody",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_u5wkb",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-01-live2d",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-01-live2d"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_USmMo",
#       "createdAt": "2025-06-20T09:36:58.000Z",
#       "updatedAt": "2025-12-24T00:27:57.000Z",
#       "slug": "hailuo-02",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/MiniMax/hailuo-02.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T06:28:00.984Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_uh4du",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/hailuo-02",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/hailuo-02"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_HMi78",
#       "createdAt": "2025-08-12T07:57:33.000Z",
#       "updatedAt": "2025-12-23T15:32:01.000Z",
#       "slug": "veo-3-0-i2v-fast",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/veo-3.0-i2v-fast.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:32:06.753Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_Lldr8",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo-3-0-i2v-fast",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo-3-0-i2v-fast"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_6Vx4g",
#       "createdAt": "2025-08-12T08:10:30.000Z",
#       "updatedAt": "2025-12-23T15:25:37.000Z",
#       "slug": "veo-3-0-fast",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/veo-3.0-fast.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:25:41.851Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_iySFE",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo-3-0-fast",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo-3-0-fast"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_2iVmk",
#       "createdAt": "2025-08-11T16:01:22.000Z",
#       "updatedAt": "2025-12-23T15:22:26.000Z",
#       "slug": "veo-3-0-i2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/veo-3.0-i2v.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:22:30.773Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_jaG7P",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo-3-0-i2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo-3-0-i2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_qRM76",
#       "createdAt": "2025-06-10T15:19:02.000Z",
#       "updatedAt": "2025-12-23T15:19:22.000Z",
#       "slug": "veo3",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/veo3.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:19:26.073Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_qKOVW",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo3",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo3"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_lFPDh",
#       "createdAt": "2025-08-11T12:26:52.000Z",
#       "updatedAt": "2025-12-23T15:13:04.000Z",
#       "slug": "veo2-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/Veo2-Image-to-Video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:13:08.351Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_jaejs",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo2-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo2-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_s3Uk2",
#       "createdAt": "2025-08-11T12:17:19.000Z",
#       "updatedAt": "2025-12-23T15:06:40.000Z",
#       "slug": "veo2",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/veo2.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:06:43.862Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_yE1XQ",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_cJ4bD",
#       "createdAt": "2025-08-13T18:22:03.000Z",
#       "updatedAt": "2025-12-23T14:30:25.000Z",
#       "slug": "seedance-1-0-pro-image-to-video-v3",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/ByteDance/seedance-1.0-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T08:30:30.391Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_EfP8p",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-pro-image-to-video-v3",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-pro-image-to-video-v3"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_zwCfI",
#       "createdAt": "2025-07-21T16:14:20.000Z",
#       "updatedAt": "2025-12-23T14:23:27.000Z",
#       "slug": "seedance-1-0-pro-text-to-video-after-repair",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/ByteDance/seedance-1.0-pro-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T08:23:31.192Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_z5hlm",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-pro-text-to-video-after-repair",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-pro-text-to-video-after-repair"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_WOuKw",
#       "createdAt": "2025-07-04T12:15:47.000Z",
#       "updatedAt": "2025-12-23T03:05:53.000Z",
#       "slug": "seedance-1-0-lite-i2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/ByteDance/seedance-1.0-lite-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:05:58.370Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_yEeKO",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-lite-i2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-lite-i2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_qRN16",
#       "createdAt": "2025-07-04T11:10:13.000Z",
#       "updatedAt": "2025-12-23T02:55:03.000Z",
#       "slug": "seedance-1-0-lite-t2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/ByteDance/seedance-1.0-lite-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T08:55:08.475Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_J8bbi",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-lite-t2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/seedance-1-0-lite-t2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_3Dhci",
#       "createdAt": "2025-12-22T11:35:59.000Z",
#       "updatedAt": "2025-12-22T15:37:56.000Z",
#       "slug": "kling-video-o1-video-to-video-reference",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-o1-video-to-video-reference.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:38:02.246Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_Rul9A",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-video-o1-video-to-video-reference",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-video-o1-video-to-video-reference"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_5Lbxv",
#       "createdAt": "2025-12-16T09:59:41.000Z",
#       "updatedAt": "2025-12-22T11:02:07.000Z",
#       "slug": "kling-video-o1-video-to-video-edit",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-o1-video-to-video-edit.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:02:14.058Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_iyGP6",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-video-o1-video-to-video-edit",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-video-o1-video-to-video-edit"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_6HK7g",
#       "createdAt": "2025-12-15T13:21:30.000Z",
#       "updatedAt": "2025-12-22T00:23:57.000Z",
#       "slug": "video-o1-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-o1-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T06:24:06.776Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_30n08",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-o1-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-o1-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_zRW1I",
#       "createdAt": "2025-12-19T15:25:51.000Z",
#       "updatedAt": "2025-12-19T17:06:17.000Z",
#       "slug": "image-o1",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/image-models/Kling-AI/image-o1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:06:28.462Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_6mYVD",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/image-o1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/image-o1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_HdPu8",
#       "createdAt": "2025-12-19T12:28:44.000Z",
#       "updatedAt": "2025-12-19T12:28:44.000Z",
#       "slug": "wan2-5-i2v-preview-2",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.5-i2v-preview.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T06:28:56.050Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_xEwn4",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-5-i2v-preview-2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-5-i2v-preview-2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_YiqPx",
#       "createdAt": "2025-12-19T11:51:51.000Z",
#       "updatedAt": "2025-12-19T11:51:51.000Z",
#       "slug": "wan2-5-t2v-preview-2",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.5-t2v-preview.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T05:52:00.087Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_6mOGw",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-5-t2v-preview-2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-5-t2v-preview-2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_lFZnh",
#       "createdAt": "2025-08-04T07:38:43.000Z",
#       "updatedAt": "2025-12-19T11:34:52.000Z",
#       "slug": "wan2-2-t2v-plus",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.2-t2v-plus.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:35:04.062Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_q4n5W",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-t2v-plus",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-t2v-plus"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_BqC6N",
#       "createdAt": "2025-08-04T06:28:58.000Z",
#       "updatedAt": "2025-12-19T11:23:21.000Z",
#       "slug": "wan2-1-t2v-turbo",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.1-t2v-turbo.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:23:31.454Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_IhJrP",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-1-t2v-turbo",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-1-t2v-turbo"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_eZuDG",
#       "createdAt": "2025-08-04T06:00:52.000Z",
#       "updatedAt": "2025-12-19T11:13:50.000Z",
#       "slug": "wan2-1-t2v-plus",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.1-t2v-plus.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:14:02.736Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_yJIOk",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-1-t2v-plus",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-1-t2v-plus"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_EBEG4",
#       "createdAt": "2025-12-19T10:12:29.000Z",
#       "updatedAt": "2025-12-19T10:12:29.000Z",
#       "slug": "v1-6-standard-multi-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-standard-multi-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:12:42.951Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_zle6C",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-6-standard-multi-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-6-standard-multi-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_ySxtY",
#       "createdAt": "2025-09-25T12:31:41.000Z",
#       "updatedAt": "2025-12-18T23:30:08.000Z",
#       "slug": "klingai-v2-5-turbo-pro-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2.5-turbo-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:30:22.967Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_xEdJw",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/klingai-v2-5-turbo-pro-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/klingai-v2-5-turbo-pro-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_QMkZ3",
#       "createdAt": "2025-09-25T09:53:28.000Z",
#       "updatedAt": "2025-12-18T23:26:52.000Z",
#       "slug": "v2-5-turbo-pro-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2.5-turbo-pro-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:27:04.384Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_ZHQ3w",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v2-5-turbo-pro-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v2-5-turbo-pro-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_4LUQm",
#       "createdAt": "2025-07-22T13:45:48.000Z",
#       "updatedAt": "2025-12-18T23:21:49.000Z",
#       "slug": "klingai-v2-1-master-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2.1-master-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:22:07.083Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_JTbrs",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/klingai-v2-1-master-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/klingai-v2-1-master-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_pe7EF",
#       "createdAt": "2025-07-22T10:18:26.000Z",
#       "updatedAt": "2025-12-18T23:17:38.000Z",
#       "slug": "klingai-v2-1-master-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2.1-master-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:17:49.167Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_c2SI5",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/klingai-v2-1-master-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/klingai-v2-1-master-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_qSf16",
#       "createdAt": "2025-08-26T18:47:56.000Z",
#       "updatedAt": "2025-12-18T23:13:15.000Z",
#       "slug": "kling-v2-1-pro-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2.1-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:13:27.546Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_YZGUe",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-1-pro-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-1-pro-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_k8c7b",
#       "createdAt": "2025-08-26T15:11:49.000Z",
#       "updatedAt": "2025-12-18T23:08:16.000Z",
#       "slug": "kling-v2-1-standard-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2.1-standard-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:08:28.191Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_E8Qdw",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-1-standard-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-1-standard-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_6MWgc",
#       "createdAt": "2025-04-25T13:57:25.000Z",
#       "updatedAt": "2025-12-18T23:03:05.000Z",
#       "slug": "kling-v2-master-i2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2-master-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:03:19.579Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_iBn6a",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-master-i2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-master-i2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_jU4LC",
#       "createdAt": "2025-04-25T14:51:24.000Z",
#       "updatedAt": "2025-12-18T22:58:09.000Z",
#       "slug": "kling-v2-master-t2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2-master-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:58:22.786Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_Vzmmu",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-master-t2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-master-t2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_e1ZGu",
#       "createdAt": "2025-04-22T08:18:41.000Z",
#       "updatedAt": "2025-12-18T22:52:12.000Z",
#       "slug": "klingai-v1-6-pro-effects",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-pro-effects.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:52:32.359Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_RjZ8T",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/klingai-v1-6-pro-effects",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/klingai-v1-6-pro-effects"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_vLWpk",
#       "createdAt": "2025-04-22T20:47:13.000Z",
#       "updatedAt": "2025-12-18T22:39:54.000Z",
#       "slug": "kling-v1-6-standard-effects",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-standard-effects.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:40:09.764Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_q4GJ3",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-v1-6-standard-effects",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-v1-6-standard-effects"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_WoIFw",
#       "createdAt": "2025-12-18T22:36:02.000Z",
#       "updatedAt": "2025-12-18T22:36:02.000Z",
#       "slug": "v1-6-pro-image-to-video-2",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:36:14.147Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_GQCYL",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-6-pro-image-to-video-2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-6-pro-image-to-video-2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_hjao5",
#       "createdAt": "2025-12-18T22:34:20.000Z",
#       "updatedAt": "2025-12-18T22:34:20.000Z",
#       "slug": "v1-6-pro-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:34:31.072Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_AisBR",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-6-pro-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-6-pro-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Nb0Gy",
#       "createdAt": "2025-12-18T22:26:00.000Z",
#       "updatedAt": "2025-12-18T22:26:00.000Z",
#       "slug": "v1-6-pro-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-pro-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:26:11.143Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_NAp0B",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-6-pro-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-6-pro-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_qTYA6",
#       "createdAt": "2025-12-18T22:20:25.000Z",
#       "updatedAt": "2025-12-18T22:20:25.000Z",
#       "slug": "v1-6-standard-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-standart-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:20:40.080Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_yJFKX",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-6-standard-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-6-standard-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_bp21Q",
#       "createdAt": "2025-12-18T22:14:20.000Z",
#       "updatedAt": "2025-12-18T22:14:20.000Z",
#       "slug": "v1-6-standard-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1.6-standard-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:14:33.471Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_E8k25",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-6-standard-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-6-standard-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_ewcSG",
#       "createdAt": "2025-12-18T22:08:27.000Z",
#       "updatedAt": "2025-12-18T22:08:27.000Z",
#       "slug": "v1-pro-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T10:08:52.325Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_JTs0Y",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-pro-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-pro-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_GnDyd",
#       "createdAt": "2025-12-18T21:18:49.000Z",
#       "updatedAt": "2025-12-18T21:18:49.000Z",
#       "slug": "v1-pro-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1-pro-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T09:19:02.063Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_ULdR0",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-pro-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-pro-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Y3NTx",
#       "createdAt": "2025-12-18T20:50:30.000Z",
#       "updatedAt": "2025-12-18T20:50:30.000Z",
#       "slug": "v1-standard-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v1-standard-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T08:50:41.653Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_E8s3e",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v1-standard-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v1-standard-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_TemWH",
#       "createdAt": "2025-12-10T21:18:09.000Z",
#       "updatedAt": "2025-12-18T18:55:21.000Z",
#       "slug": "v5-5-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/PixVerse/v5.5-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T06:55:32.184Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_5SN9d",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v5-5-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v5-5-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_2l9Wk",
#       "createdAt": "2025-11-14T14:47:28.000Z",
#       "updatedAt": "2025-12-18T18:08:37.000Z",
#       "slug": "gpt-5-1",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T06:08:52.692Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_TNSyr",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_wVu1n",
#       "createdAt": "2025-12-18T09:53:50.000Z",
#       "updatedAt": "2025-12-18T11:27:16.000Z",
#       "slug": "gemini-3-flash-preview",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Google/gemini-3-flash-preview.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T11:27:28.932Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_WvsEB",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gemini-3-flash-preview",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gemini-3-flash-preview"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_iDCkT",
#       "createdAt": "2025-12-17T18:06:44.000Z",
#       "updatedAt": "2025-12-17T18:16:06.000Z",
#       "slug": "flux-2-max",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/image-models/black-forest-labs/flux-2-max.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-24T06:16:28.766Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_gmgkU",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/flux-2-max",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/flux-2-max"
#       }
#     },
#     {
# ...
#  ✓ Updated
# Updating: whisper-medium-2025-05-28
#  ✓ Updated
# Updating: whisper-small-2025-05-28
#  ✓ Updated
# Updating: whisper-tiny-2025-05-28
#  ✓ Updated
# Updating: luma-t2v-v2
#  ✓ Updated
# Updating: lyria2
#  ✓ Updated
# Updating: bagoodex-links
#  ✓ Updated
# Updating: lyria2-fetch
#  ✓ Updated
# Updating: gemma-3n
#  ✓ Updated
# Updating: bagoodex-images
#  ✓ Updated
# Updating: bagoodex-videos
#  ✓ Updated
# Updating: bagoodex-weather
#  ✓ Updated
# Updating: bagoodex-map
#  ✓ Updated
# Updating: bagoodex-knowledge
#  ✓ Updated
# Updating: ass-ass-list
#  ✓ Updated
# Updating: ass-ass-info-id
#  ✓ Updated
# Updating: ass-ass-modify
#  ✓ Updated
# Updating: ass-ass-delete
#  ✓ Updated
# Updating: ass-thread-info-id
#  ✓ Updated
# Updating: ass-threads-create
#  ✓ Updated
# Updating: ass-threads-modify
#  ✓ Updated
# Updating: ass-threads-delete
#  ✓ Updated
# Updating: luma-gen-fetch
#  ✓ Updated
# Updating: luma-gens-fetch
#  ✓ Updated
# Updating: luma-v1-fetch
#  ✓ Updated
# Updating: luma-v2-extend
#  ✓ Updated
# Updating: models
#  ✓ Updated
# Updating: ass-msg-create
#  ✓ Updated
# Updating: stt-legacy
#  ✓ Updated
# Updating: ass-msg-list
#  ✓ Updated
# Updating: ass-msg-info
#  ✓ Updated
# Updating: ass-msg-modify
#  ✓ Updated
# Updating: ass-msg-delete
#  ✓ Updated
# Updating: ass-runs-create
#  ✓ Updated
# Updating: ass-runs-create-n-run
#  ✓ Updated
# Updating: ass-runs-get-list
#  ✓ Updated
# Updating: ass-runs-runinfo
#  ✓ Updated
# Updating: ass-runs-runmodify
#  ✓ Updated
# Updating: ass-runs-submit-tool-outputs
#  ✓ Updated
# Updating: ass-runs-cancel
#  ✓ Updated
# Updating: ass-runs-steps-list
#  ✓ Updated
# Updating: ass-runs-stepinfo
#  ✓ Updated
# Updating: vision-ofr
#  ✓ Updated
# Updating: anthropic-messages
#  ✓ Updated
# Updating: test-constructor
#  ✓ Updated
# Updating: test-constructor-2
#  ✓ Updated
# Updating: veo3-fetch
#  ✓ Updated
# Updating: flux-kontext-pro
#  ✓ Updated
# Updating: flux-kontext-pro-2025-06-11
#  ✓ Updated
# Updating: gpt-image-1
#  ✓ Updated
# Updating: local-gemini-2-5-flash-preview
#  ✓ Updated
# Updating: qwen2-72b-instruct
#  ✓ Updated
# Updating: qwen2-5-72b-instruct-turbo
#  ✓ Updated
# Updating: qwen2-72b-instruct-2nd-try
#  ✓ Updated
# Updating: qwen2-5-7b-instruct-turbo
#  ✓ Updated
# Updating: qwen-qwq-32b
#  ✓ Updated
# Updating: qwen2-5-coder-32b-instruct
#  ✓ Updated
# Updating: magnum-v4
#  ✓ Updated
# Updating: claude-3-haiku
#  ✓ Updated
# Updating: claude-3-opus
#  ✓ Updated
# Updating: claude-3-sonnet
#  ✓ Updated
# Updating: claude-3-5-sonnet
#  ✓ Updated
# Updating: claude-3-7-sonnet
#  ✓ Updated
# Updating: claude-4-sonnet
#  ✓ Updated
# Updating: claude-4-opus
#  ✓ Updated
# Updating: command-r-plus
#  ✓ Updated
# Updating: deepseek-chat-v3
#  ✓ Updated
# Updating: deepseek-r1
#  ✓ Updated
# Updating: gemini-2-0-flash
#  ✓ Updated
# Updating: gemini-2-5-pro-preview
#  ✓ Updated
# Updating: gemma-2-27b-it
#  ✓ Updated
# Updating: llama-3-chat-hf
#  ✓ Updated
# Updating: gemini-1-5-flash
#  ✓ Updated
# Updating: gemini-1-5-pro
#  ✓ Updated
# Updating: gemini-2-5-pro-exp
#  ✓ Updated
# Updating: llama-3-chat-h-f
#  ✓ Updated
# Updating: mythomax-l2-13b-lite
#  ✓ Updated
# Updating: meta-llama-3-8b-instruct-lite
#  ✓ Updated
# Updating: meta-llama-3-1-8b-instruct-turbo
#  ✓ Updated
# Updating: llama-3-2-11b-vision-instruct-turbo
#  ✓ Updated
# Updating: llama-3-2-90b-vision-instruct-turbo
#  ✓ Updated
# Updating: llama-3-2-3b-instruct-turbo
#  ✓ Updated
# Updating: llama-vision-free
#  ✓ Updated
# Updating: llama-3-3-70b-instruct-turbo
#  ✓ Updated
# Updating: llama-4-maverick
#  ✓ Updated
# Updating: llama-4-scout
#  ✓ Updated
# Updating: text-01
#  ✓ Updated
# Updating: abab6-5s-chat
#  ✓ Updated
# Updating: codestral-2501
#  ✓ Updated
# Updating: mistral-nemo
#  ✓ Updated
# Updating: mistral-tiny
#  ✓ Updated
# Updating: mixtral-8x22b-instruct
#  ✓ Updated
# Updating: mixtral-8x7b-instruct
#  ✓ Updated
# Updating: llama-3-1-nemotron-70b
#  ✓ Updated
# Updating: llama-3-1-nemotron-70b-instruct-hf
#  ✓ Updated
# Updating: llama-3-1-lumimaid
#  ✓ Updated
# Updating: nous-hermes-2-mixtral-8x7b-dpo
#  ✓ Updated
# Updating: gpt-image-1-edit
#  ✓ Updated
# Updating: nous-hermes-2-mixtral-8-7b-dpo
#  ✓ Updated
# Updating: gpt-4-5-preview
#  ✓ Updated
# Updating: o1-preview
#  ✓ Updated
# Updating: grok-beta
#  ✓ Updated
# Updating: grok-3-mini-beta
#  ✓ Updated
# Updating: nous-hermes-2
#  ✓ Updated
# Updating: gemma-3
#  ✓ Updated
# Updating: m2-bert-80m-retrieval
#  ✓ Updated
# Updating: bytedance-video-fetch
#  ✓ Updated
# Updating: o3-pro-response-api
#  ✓ Updated
# Updating: o3-pro-response
#  ✓ Updated
# Updating: gemini-2-5-flash-lite-preview
#  ✓ Updated
# Updating: responses-all-models
#  ✓ Updated
# Updating: command-a
#  ✓ Updated
# Updating: seedance-1-0-pro-t2v
#  ✓ Updated
# Updating: seedance-1-0-pro-text-to-video
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video
#  ✓ Updated
# Updating: test-20250721
#  ✓ Updated
# Updating: test-202250721-02
#  ✓ Updated
# Updating: test-20250721-03
#  ✓ Updated
# Updating: test-20250721-04
#  ✓ Updated
# Updating: test-20250721-05
#  ✓ Updated
# Updating: test-20250721-06
#  ✓ Updated
# Updating: grok-4
#  ✓ Updated
# Updating: google-ocr
#  ✓ Updated
# Updating: google-ocr-last
#  ✓ Updated
# Updating: google-ocr-new
#  ✓ Updated
# Updating: mistral-ocr-latest
#  ✓ Updated
# Updating: gemini-2-5-flash
#  ✓ Updated
# Updating: mistral-ocr-last
#  ✓ Updated
# Updating: gemini-2-5-pro
#  ✓ Updated
# Updating: qwen3-32b
#  ✓ Updated
# Updating: qwen3-235b-a22b-thinking-2507
#  ✓ Updated
# Updating: eleven-multilingual-v2
#  ✓ Updated
# Updating: qwen3-coder-480b-a35b-instruct
#  ✓ Updated
# Updating: eleven-turbo-v2-5
#  ✓ Updated
# Updating: glm-4-5
#  ✓ Updated
# Updating: glm-4-5-air
#  ✓ Updated
# Updating: horizon-alpha
#  ✓ Updated
# Updating: horizon-beta
#  ✓ Updated
# Updating: wan2-2-i2v-plus
#  ✓ Updated
# Updating: ass-ass-create
#  ✓ Updated
# Updating: runway-fetch
#  ✓ Updated
# Updating: runway-gen3a-turbo
#  ✓ Updated
# Updating: runway-gen4-turbo
#  ✓ Updated
# Updating: claude-opus-4-1
#  ✓ Updated
# Updating: runway-act-two
#  ✓ Updated
# Updating: runway-gen4-aleph
#  ✓ Updated
# Updating: gpt-5
#  ✓ Updated
# Updating: fetch-google-veos
#  ✓ Updated
# Updating: gpt-5-mini
#  ✓ Updated
# Updating: slam-1
#  ✓ Updated
# Updating: aai-universal
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video-v2
#  ✓ Updated
# Updating: m2-bert-80m-retrieval-v2
#  ✓ Updated
# Updating: triposr
#  ✓ Updated
# Updating: triposr-test-without-code-samles
#  ✓ Updated
# Updating: test-no-codesample-02
#  ✓ Updated
# Updating: test-no-codesamples-01
#  ✓ Updated
# Updating: test-no-codesample-03
#  ✓ Updated
# Updating: response-api
#  ✓ Updated
# Updating: minimax-music
#  ✓ Updated
# Updating: minimax-music-fetch
#  ✓ Updated
# Updating: deepseek-reasoner-v3-1
#  ✓ Updated
# Updating: speech-2-5-hd-preview
#  ✓ Updated
# Updating: eleven-music
#  ✓ Updated
# Updating: speech-2-5-turbo-preview
#  ✓ Updated
# Updating: eleven-music-fetch
#  ✓ Updated
# Updating: v3-alpha
#  ✓ Updated
# Updating: vibevoice-1-5b
#  ✓ Updated
# Updating: vibevoice-7b
#  ✓ Updated
# Updating: gpt-5-chat
#  ✓ Updated
# Updating: gpt-5-nano
#  ✓ Updated
# Updating: gemma-3n-e4b-it
#  ✓ Updated
# Updating: qwen3-next-80b-a3b-instruct
#  ✓ Updated
# Updating: qwen3-next-80b-a3b-thinking
#  ✓ Updated
# Updating: pixverse-fetch
#  ✓ Updated
# Updating: v1-6-standart-image-to-video
#  ✓ Updated
# Updating: pixverse-v5-image-to-video
#  ✓ Updated
# Updating: pixverse-v5-transition
#  ✓ Updated
# Updating: klingai-v1-6-standard-multi-image-to-video
#  ✓ Updated
# Updating: wan2-5-t2v-preview
#  ✓ Updated
# Updating: wan2-5-i2v-preview
#  ✓ Updated
# Updating: qwen3-max-preview
#  ✓ Updated
# Updating: universal-video-endpoint-fetch
#  ✓ Updated
# Updating: omnihuman
#  ✓ Updated
# Updating: qwen3-max-instruct
#  ✓ Updated
# Updating: test-scalar-chatgpt-4o-latest
#  ✓ Updated
# Updating: grok-4-fast-non-reasoning
#  ✓ Updated
# Updating: grok-4-fast-reasoning
#  ✓ Updated
# Updating: reve-edit-image
#  ✓ Updated
# Updating: deepseek-non-thinking-v3-2
#  ✓ Updated
# Updating: reve-remix-edit-image
#  ✓ Updated
# Updating: wan2-2-14b-animate-replace
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-pose
#  ✓ Updated
# Updating: fabric-1-0-pair
#  ✓ Updated
# Updating: qwen3-tts-flash
#  ✓ Updated
# Updating: veo-3-1-t2v
#  ✓ Updated
# Updating: fetch-video
#  ✓ Updated
# Updating: gpt-4o-mini-tts
#  ✓ Updated
# Updating: tts-1-hd
#  ✓ Updated
# Updating: tts-1
#  ✓ Updated
# Updating: deepseek-non-reasoner-v3-1-terminus
#  ✓ Updated
# Updating: deepseek-reasoner-v3-1-terminus
#  ✓ Updated
# Updating: kandinsky5-t2v
#  ✓ Updated
# Updating: fetch-video-universal-endpoint
#  ✓ Updated
# Updating: kandinsky5-distill-t2v
#  ✓ Updated
# Updating: grok-2-image
#  ✓ Updated
# Updating: batch
#  ✓ Updated
# Updating: ray-1-6
#  ✓ Updated
# Updating: batch-get
#  ✓ Updated
# Updating: batch-cancel
#  ✓ Updated
# Updating: ray-2
#  ✓ Updated
# Updating: krea-wan-14b-text-to-video
#  ✓ Updated
# Updating: krea-wan-14b-video-to-video
#  ✓ Updated
# Updating: ray-flash-2
#  ✓ Updated
# Updating: aura-2
#  ✓ Updated
# Updating: kimi-k2-turbo-preview
#  ✓ Updated
# Updating: m2
#  ✓ Updated
# Updating: moonshot-kimi-k2-preview
#  ✓ Updated
# Updating: omnihuman-v-1-5
#  ✓ Updated
# Updating: nemotron-nano-12b-v2-vl
#  ✓ Updated
# Updating: nemotron-nano-9b-v2
#  ✓ Updated
# Updating: speech-2-6-hd
#  ✓ Updated
# Updating: music-1-5
#  ✓ Updated
# Updating: speech-2-6-turbo
#  ✓ Updated
# Updating: sora-2-t2v
#  ✓ Updated
# Updating: sora-2-i2v
#  ✓ Updated
# Updating: sora-2-t2v-pair
#  ✓ Updated
# Updating: sora-2-pro-t2v
#  ✓ Updated
# Updating: sora-2-pro-i2v
#  ✓ Updated
# Updating: qwen-max
#  ✓ Updated
# Updating: qwen-plus
#  ✓ Updated
# Updating: deepseek-chat-v3-1
#  ✓ Updated
# Updating: deepseek-thinking-v3-2
#  ✓ Updated
# Updating: deepseek-thinking-v3-2-exp
#  ✓ Updated
# Updating: deepseek-non-thinking-v3-2-exp
#  ✓ Updated
# Updating: hermes-4-405b
#  ✓ Updated
# Updating: m1
#  ✓ Updated
# Updating: o1-mini
#  ✓ Updated
# Updating: sonar
#  ✓ Updated
# Updating: sonar-pro
#  ✓ Updated
# Updating: grok-3-beta
#  ✓ Updated
# Updating: grok-code-fast-1
#  ✓ Updated
# Updating: gpt-5-1-chat-latest
#  ✓ Updated
# Updating: gemini-2-0-flash-exp
#  ✓ Updated
# Updating: gpt-5-1-chat-latest-RESPONSES
#  ✓ Updated
# Updating: meta-llama-3-1-70b-instruct-turbo
#  ✓ Updated
# Updating: llama-3-3-70b-versatile
#  ✓ Updated
# Updating: meta-llama-3-1-405b-instruct-turbo
#  ✓ Updated
# Updating: bagoodex-search
#  ✓ Updated
# Updating: alibaba-fetch
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-reframe
#  ✓ Updated
# Updating: wan-2-2-vace-fun-a14b-inpainting
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-outpainting
#  ✓ Updated
# Updating: veo-3-1-first-last-image-to-video-fast
#  ✓ Updated
# Updating: avatar-standard
#  ✓ Updated
# Updating: avatar-pro
#  ✓ Updated
# Updating: luma-v1-gen
#  ✓ Updated
# Updating: ltxv-2
#  ✓ Updated
# Updating: ltxv-2-test
#  ✓ Updated
# Updating: fabric-1-0
#  ✓ Updated
# Updating: fabric-1-0-fast
#  ✓ Updated
# Updating: ltxv-2-fast
#  ✓ Updated
# Updating: gemini-3-pro-preview
#  ✓ Updated
# Updating: veo-3-1-first-last-image-to-video
#  ✓ Updated
# Updating: veo-3-1-i2v
#  ✓ Updated
# Updating: veo-3-1-reference-to-video
#  ✓ Updated
# Updating: veo-3-1-i2v-fast
#  ✓ Updated
# Updating: veo-3-1-t2v-fast
#  ✓ Updated
# Updating: gemini-2-5-flash-image-edit
#  ✓ Updated
# Updating: gpt-5-1-RESPONSES
#  ✓ Updated
# Updating: gpt-5-nano-RESPONSES
#  ✓ Updated
# Updating: gpt-5-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-5-RESPONSES
#  ✓ Updated
# Updating: o1-RESPONSES
#  ✓ Updated
# Updating: o3-RESPONSES
#  ✓ Updated
# Updating: gpt-4-RESPONSES
#  ✓ Updated
# Updating: gpt-4o-RESPONSES
#  ✓ Updated
# Updating: gpt-4-preview-RESPONSES
#  ✓ Updated
# Updating: grok-4-1-fast-reasoning
#  ✓ Updated
# Updating: grok-4-1-fast-non-reasoning
#  ✓ Updated
# Updating: qwen-image
#  ✓ Updated
# Updating: qwen-image-edit
#  ✓ Updated
# Updating: bytedance-seedream-3-0
#  ✓ Updated
# Updating: flux-pro
#  ✓ Updated
# Updating: seedream-v4-text-to-image
#  ✓ Updated
# Updating: flux-pro-v1-1
#  ✓ Updated
# Updating: flux-pro-v1-1-ultra
#  ✓ Updated
# Updating: flux-realism
#  ✓ Updated
# Updating: flux-dev
#  ✓ Updated
# Updating: flux-dev-image-to-image
#  ✓ Updated
# Updating: flux-schnell
#  ✓ Updated
# Updating: flux-kontext-max
#  ✓ Updated
# Updating: flux-kontext-max-image-to-image
#  ✓ Updated
# Updating: flux-kontext-pro-image-to-image
#  ✓ Updated
# Updating: flux-srpo
#  ✓ Updated
# Updating: imagen-3
#  ✓ Updated
# Updating: imagen-4-0-ultra
#  ✓ Updated
# Updating: imagen-4-preview
#  ✓ Updated
# Updating: imagen-4-0-generate-001
#  ✓ Updated
# Updating: imagen-4-0-fast-generate-001
#  ✓ Updated
# Updating: imagen-4-0-ultra-generate-001
#  ✓ Updated
# Updating: gemini-2-5-flash-image
#  ✓ Updated
# Updating: dall-e-2
#  ✓ Updated
# Updating: dall-e-3
#  ✓ Updated
# Updating: gpt-image-1-gen
#  ✓ Updated
# Updating: recraft-v3
#  ✓ Updated
# Updating: reve-create-image
#  ✓ Updated
# Updating: stable-diffusion-v3-medium
#  ✓ Updated
# Updating: stable-diffusion-v35-large
#  ✓ Updated
# Updating: hunyuan-image-v3-text-to-image
#  ✓ Updated
# Updating: sharpen
#  ✓ Updated
# Updating: sharpen-gen
#  ✓ Updated
# Updating: flux-kontext-pro-try-3
#  ✓ Updated
# Updating: flux-srpo-image-to-image
#  ✓ Updated
# Updating: seededit-3-0-i2i
#  ✓ Updated
# Updating: seedream-v4-edit
#  ✓ Updated
# Updating: uso
#  ✓ Updated
# Updating: gpt-3-5-turbo-RESPONSES
#  ✓ Updated
# Updating: gpt-4-turbo-RESPONSES
#  ✓ Updated
# Updating: gpt-4o-mini-RESPONSES
#  ✓ Updated
# Updating: o3-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-nano-RESPONSES
#  ✓ Updated
# Updating: o4-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-5-chat-RESPONSES
#  ✓ Updated
# Updating: gpt-5-mini-RESPONSES-v2
#  ✓ Updated
# Updating: qwen-turbo
#  ✓ Updated
# Updating: claude-opus-4-5
#  ✓ Updated
# Updating: inworld-tts-1
#  ✓ Updated
# Updating: inworld-tts-1-max
#  ✓ Updated
# Updating: flux-2-pro
#  ✓ Updated
# Updating: flux-2-pro-edit
#  ✓ Updated
# Updating: flux-2-edit
#  ✓ Updated
# Updating: flux-2-lora
#  ✓ Updated
# Updating: flux-2-lora-edit
#  ✓ Updated
# Updating: qwen3-vl-32b-instruct
#  ✓ Updated
# Updating: qwen3-vl-32b-thinking
#  ✓ Updated
# Updating: mistral-7b-instruct
#  ✓ Updated
# Updating: pixverse-v5-text-to-video
#  ✓ Updated
# Updating: z-image-turbo
#  ✓ Updated
# Updating: z-image-turbo-lora
#  ✓ Updated
# Updating: gpt-3-5-turbo
#  ✓ Updated
# Updating: gpt-4o
#  ✓ Updated
# Updating: gpt-4o-mini
#  ✓ Updated
# Updating: gpt-4o-audio-preview
#  ✓ Updated
# Updating: gpt-4o-mini-audio-preview
#  ✓ Updated
# Updating: gpt-4o-mini-search-preview
#  ✓ Updated
# Updating: gpt-4o-search-preview
#  ✓ Updated
# Updating: gpt-4
#  ✓ Updated
# Updating: gpt-4-turbo
#  ✓ Updated
# Updating: gpt-4-preview
#  ✓ Updated
# Updating: o1
#  ✓ Updated
# Updating: o3
#  ✓ Updated
# Updating: o3-mini
#  ✓ Updated
# Updating: gpt-4-1-mini
#  ✓ Updated
# Updating: o3-pro-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-nano
#  ✓ Updated
# Updating: gpt-oss-20b
#  ✓ Updated
# Updating: o4-mini
#  ✓ Updated
# Updating: gpt-oss-120b
#  ✓ Updated
# Updating: gpt-4-1
#  ✓ Updated
# Updating: gpt-5-test
#  ✓ Updated
# Updating: glm-4-6
#  ✓ Updated
# Updating: video-v2-6-pro-text-to-video
#  ✓ Updated
# Updating: claude-3-5-haiku
#  ✓ Updated
# Updating: anthropic-claude-sonnet-4-5
#  ✓ Updated
# Updating: claude-haiku-4-5
#  ✓ Updated
# Updating: qwen3-omni-30b-a3b-captioner
#  ✓ Updated
# Updating: billing-test-1
#  ✓ Updated
# Updating: gpt-5-1-codex-mini
#  ✓ Updated
# Updating: video-v2-6-pro-image-to-video
#  ✓ Updated
# Updating: gemini-3-pro-image-preview
#  ✓ Updated
# Updating: gemini-3-pro-image-preview-edit
#  ✓ Updated
# Updating: batch-cancel-2
#  ✓ Updated
# Updating: mythomax-l2-13b
#  ✓ Updated
# Updating: wan2-2-14b-animate-move
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-depth
#  ✓ Updated
# Updating: kling-fetch
#  ✓ Updated
# Updating: v5-5-image-to-video
#  ✓ Updated
# Updating: qwen-text-embedding-v4-and-v3
#  ✓ Updated
# Updating: model
#  ✓ Updated
# Updating: qwen-text-embedding-v4
#  ✓ Updated
# Updating: flux-2
#  ✓ Updated
# Updating: gpt-5-2
#  ✓ Updated
# Updating: gpt-5-2-chat-latest
#  ✓ Updated
# Updating: gpt-5-2-pro-RESPONSES
#  ✓ Updated
# Updating: kling-o1
#  ✓ Updated
# Updating: kling-o1-models
#  ✓ Updated
# Updating: kling-image-o1-kling-video-o1
#  ✓ Updated
# Updating: kling-image-o1
#  ✓ Updated
# Updating: d1m7-auto-kling-image-o1
#  ✓ Updated
# Updating: d1m7-auto-gpt-5-1
#  ✓ Updated
# Updating: pixverse-v5-5-text-to-video
#  ✓ Updated
# Updating: gpt-5-2-openai
#  ✓ Updated
# Updating: gpt-5-pro-RESPONSES
#  ✓ Updated
# Updating: pixverse-v5-5-image-to-video
#  ✓ Updated
# Updating: kling-2-6-pro-image-to-video
#  ✓ Updated
# Updating: longcat-video-distilled
#  ✓ Updated
# Updating: seedream-4-5
#  ✓ Updated
# Updating: gpt-5-1-codex
#  ✓ Updated
# Updating: claude-sonnet-4-5
#  ✓ Updated
# Skipped: missing slug or sourceURL → oas_lGUbh
# Skipped: missing slug or sourceURL → oas_UcQoB
#
# ====== SUMMARY ======
# Total specs      : 467
# Updated          : 465
# Failed updates   : 0
# Skipped          : 2
# =====================

# %% [markdown]
# ## обновить прицельно одну апи-схему по её названию и URL

# %%
import requests
import time
import json

# —————————————————————————
# Настройки
TOKEN = "gb_api_vVVR78hJXh8dkcFDRtgn9LBHtFTQUmWAkQDdXe8q"
ORG_ID = "isNk5xPnJebTWJa4JCg5"

BASE_URL = "https://api.gitbook.com/v1"

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json",
    "Accept": "application/json",
}

# —————————————————————————
def list_openapi_specs():
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi?limit=1000"
    resp = requests.get(url, headers=HEADERS)
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    resp.raise_for_status()
    return resp.json().get("items", [])

def update_spec(spec_slug, source_url):
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi/{spec_slug}"
    body = {
        "source": {
            "url": source_url
        }
    }
    resp = requests.put(url, json=body, headers=HEADERS)
    resp.raise_for_status()
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    return resp.json()

def main():
    
    slug = "gpt-5-1-codex"
    source_url = "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-RESPONSES.json"
    print(f"Updating: {slug}")

    try:
        update_spec(slug, source_url)
        updated += 1
        print(f" ✓ Updated")
    except Exception as e:
        failed += 1
        print(f" ✗ Failed: {e}")

    # защита от rate-limit
    time.sleep(0.2)


if __name__ == "__main__":
    main()
# Out:
# Updating: gpt-5-1-codex
# {
#   "object": "openapi-spec",
#   "id": "oas_gT3IR",
#   "createdAt": "2025-11-14T15:07:27.000Z",
#   "updatedAt": "2025-12-16T11:31:34.000Z",
#   "slug": "gpt-5-1-codex",
#   "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-RESPONSES.json",
#   "processingState": "pending",
#   "visibility": "private",
#   "lastProcessedAt": "2025-12-16T11:28:57.146Z",
#   "lastProcessedErrors": [
#     {
#       "path": "/paths/~1v1~1responses/post/responses/200",
#       "message": "must have required property '$ref'"
#     }
#   ],
#   "lastVersion": "oasv_BGiGW",
#   "permissions": {
#     "view": true,
#     "edit": true
#   },
#   "urls": {
#     "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex",
#     "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex"
#   }
# }
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 48, in main()
#      47 update_spec(slug, source_url)
# ---> 48 updated += 1
#      49 print(f" ✓ Updated")
#
# UnboundLocalError: cannot access local variable 'updated' where it is not associated with a value
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 59
#      55     time.sleep(0.2)
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[9], line 51, in main()
#      49     print(f" ✓ Updated")
#      50 except Exception as e:
# ---> 51     failed += 1
#      52     print(f" ✗ Failed: {e}")
#      54 # защита от rate-limit
#
# UnboundLocalError: cannot access local variable 'failed' where it is not associated with a value
