# %% [markdown]
# ## найти все апи-схемы в нашей системе и принудительно обновить

# %%
import requests
import time
import json

# —————————————————————————
# Настройки
TOKEN = "gb_api_vVVR78hJXh8dkcFDRtgn9LBHtFTQUmWAkQDdXe8q"
ORG_ID = "isNk5xPnJebTWJa4JCg5"

BASE_URL = "https://api.gitbook.com/v1"

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json",
    "Accept": "application/json",
}

# —————————————————————————
def list_openapi_specs():
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi?limit=1000"
    resp = requests.get(url, headers=HEADERS)
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    resp.raise_for_status()
    return resp.json().get("items", [])

def update_spec(spec_slug, source_url):
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi/{spec_slug}"
    body = {
        "source": {
            "url": source_url
        }
    }
    resp = requests.put(url, json=body, headers=HEADERS)
    resp.raise_for_status()
    return resp.json()

def main():
    specs = list_openapi_specs()

    total = len(specs)
    updated = 0
    failed = 0
    skipped = 0

    print(f"Found {total} OpenAPI specs\n")

    for spec in specs:
        slug = spec.get("slug")
        source_url = spec.get("sourceURL")

        if not slug or not source_url:
            skipped += 1
            print(f"Skipped: missing slug or sourceURL → {spec.get('id', 'unknown')}")
            continue

        print(f"Updating: {slug}")

        try:
            update_spec(slug, source_url)
            updated += 1
            print(f" ✓ Updated")
        except Exception as e:
            failed += 1
            print(f" ✗ Failed: {e}")

        # защита от rate-limit
        time.sleep(0.2)

    # —————————————————————————
    print("\n====== SUMMARY ======")
    print(f"Total specs      : {total}")
    print(f"Updated          : {updated}")
    print(f"Failed updates   : {failed}")
    print(f"Skipped          : {skipped}")
    print("=====================")


if __name__ == "__main__":
    main()
# Out:
# {
#   "items": [
#     {
#       "object": "openapi-spec",
#       "id": "oas_gT3IR",
#       "createdAt": "2025-11-14T15:07:27.000Z",
#       "updatedAt": "2025-12-16T11:31:34.000Z",
#       "slug": "gpt-5-1-codex",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-RESPONSES.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:31:38.796Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1responses/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_BGiGW",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_my0NK",
#       "createdAt": "2025-12-08T20:30:29.000Z",
#       "updatedAt": "2025-12-16T10:21:03.000Z",
#       "slug": "seedream-4-5",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/image-models/ByteDance/seedream-4-5.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:21:05.522Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_ek0S3",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/seedream-4-5",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/seedream-4-5"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_bpG2Q",
#       "createdAt": "2025-12-10T11:49:28.000Z",
#       "updatedAt": "2025-12-16T10:10:41.000Z",
#       "slug": "deepseek-v3-2-speciale",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/text-models-llm/DeepSeek/deepseek-v3-2-speciale.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:10:43.906Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_gm9r2",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/deepseek-v3-2-speciale",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/deepseek-v3-2-speciale"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_otnKV",
#       "createdAt": "2025-12-16T10:07:36.000Z",
#       "updatedAt": "2025-12-16T10:07:36.000Z",
#       "slug": "longcat-video-distilled",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/longcat/longcat-video-distilled.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:07:44.280Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_ZTYAl",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/longcat-video-distilled",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/longcat-video-distilled"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_6HPWg",
#       "createdAt": "2025-12-09T19:32:48.000Z",
#       "updatedAt": "2025-12-16T10:02:23.000Z",
#       "slug": "kling-2-6-pro-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/kling-ai/kling-2-6-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:02:29.997Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_bOegk",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-2-6-pro-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-2-6-pro-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_5Lbxv",
#       "createdAt": "2025-12-16T09:59:41.000Z",
#       "updatedAt": "2025-12-16T09:59:41.000Z",
#       "slug": "kling-video-o1-video-to-video-edit",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/Kling-AI/kling-video-o1-video-to-video-edit.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:59:49.184Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_bOexr",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-video-o1-video-to-video-edit",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-video-o1-video-to-video-edit"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_xiuFq",
#       "createdAt": "2025-12-16T09:56:12.000Z",
#       "updatedAt": "2025-12-16T09:56:12.000Z",
#       "slug": "pixverse-v5-5-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/PixVerse/pixverse-v5-5-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:56:22.974Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_sWFOf",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/pixverse-v5-5-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/pixverse-v5-5-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_VMOAS",
#       "createdAt": "2025-12-16T09:51:25.000Z",
#       "updatedAt": "2025-12-16T09:51:25.000Z",
#       "slug": "gpt-5-2-openai",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/text-models-llm/OpenAI/gpt-5-2-openai.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:51:28.313Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_HNZOn",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2-openai",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2-openai"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_AOBLJ",
#       "createdAt": "2025-11-27T11:29:42.000Z",
#       "updatedAt": "2025-12-15T15:40:47.000Z",
#       "slug": "gpt-5-pro-RESPONSES",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-pro-RESPONSES.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:02:50.535Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1responses/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_oLvKz",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-pro-RESPONSES",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-pro-RESPONSES"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_g8LQR",
#       "createdAt": "2025-12-15T13:48:11.000Z",
#       "updatedAt": "2025-12-15T14:33:13.000Z",
#       "slug": "pixverse-v5-5-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/PixVerse/pixverse-v5-5-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:58:49.834Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_YJqcj",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/pixverse-v5-5-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/pixverse-v5-5-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_6HK7g",
#       "createdAt": "2025-12-15T13:21:30.000Z",
#       "updatedAt": "2025-12-15T13:21:30.000Z",
#       "slug": "video-o1-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-o1-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:47:52.159Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_EHmWd",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-o1-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-o1-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_2l9Wk",
#       "createdAt": "2025-11-14T14:47:28.000Z",
#       "updatedAt": "2025-12-15T11:50:46.000Z",
#       "slug": "gpt-5-1",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/b7d2172219e83e563dfe5e2e388a3135104b719f/docs/api-references/text-models-llm/openai/gpt-5-1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:42:01.784Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_RmR02",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_HGnT8",
#       "createdAt": "2025-12-12T22:42:42.000Z",
#       "updatedAt": "2025-12-15T09:37:09.000Z",
#       "slug": "d1m7-auto-gpt-5-1",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/1c535c0b767e79b5c2704ba0128ca25a6c4f5973/docs/api-references/text-models-llm/openai/d1m7-auto-gpt-5-1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:36:11.178Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_0D0l2",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/d1m7-auto-gpt-5-1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/d1m7-auto-gpt-5-1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_25LSk",
#       "createdAt": "2025-12-12T22:16:00.000Z",
#       "updatedAt": "2025-12-12T22:30:35.000Z",
#       "slug": "d1m7-auto-kling-image-o1",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/548b2666760ec15b95e398c8cd4a0b56125b8e13/docs/api-references/image-models/kling-ai/d1m7-auto-kling-image-o1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T08:44:18.861Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_NenJQ",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/d1m7-auto-kling-image-o1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/d1m7-auto-kling-image-o1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_5Lxzv",
#       "createdAt": "2025-12-12T12:43:30.000Z",
#       "updatedAt": "2025-12-12T12:43:44.000Z",
#       "slug": "kling-image-o1",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/cc27585449e0e4520e2f021b60ca24f60e89ac81/docs/api-references/autoDoc/kling-image-o1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:29:54.467Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_8BgD0",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-image-o1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-image-o1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_c1gaD",
#       "createdAt": "2025-12-12T10:38:21.000Z",
#       "updatedAt": "2025-12-12T10:38:21.000Z",
#       "slug": "kling-image-o1-kling-video-o1",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/0e7880debcc1ebdd68e629bc5a59dbbe0399dfcf/docs/api-references/autoDoc/kling-image-o1-kling-video-o1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T08:55:58.685Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_gEjLa",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-image-o1-kling-video-o1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-image-o1-kling-video-o1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_QFuR3",
#       "createdAt": "2025-12-12T10:20:19.000Z",
#       "updatedAt": "2025-12-12T10:20:19.000Z",
#       "slug": "kling-o1",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/25d36d7d4930b0964dde5a22e1b095b6aac8f63d/docs/api-references/autoDoc/kling-o1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T08:30:32.401Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_NeJPs",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-o1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-o1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_kvjBb",
#       "createdAt": "2025-12-12T10:08:52.000Z",
#       "updatedAt": "2025-12-12T10:08:52.000Z",
#       "slug": "kling-o1-models",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/2c1e462b47e633f8d3e3accd939c2705f65bbefc/docs/api-references/autoDoc/kling-o1-models.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T08:17:08.024Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_yGZCC",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-o1-models",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-o1-models"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_NbhVy",
#       "createdAt": "2025-12-11T23:17:15.000Z",
#       "updatedAt": "2025-12-11T23:17:15.000Z",
#       "slug": "gpt-5-2-pro-RESPONSES",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-2-pro-RESPONSES.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:26:12.765Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1responses/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_gEFVv",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2-pro-RESPONSES",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2-pro-RESPONSES"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_RPekU",
#       "createdAt": "2025-12-11T23:12:51.000Z",
#       "updatedAt": "2025-12-11T23:12:51.000Z",
#       "slug": "gpt-5-2-chat-latest",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-2-chat-latest.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:23:19.377Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_6ZvqA",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2-chat-latest",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2-chat-latest"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_qTFC6",
#       "createdAt": "2025-12-11T23:06:11.000Z",
#       "updatedAt": "2025-12-11T23:06:11.000Z",
#       "slug": "gpt-5-2",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-2.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:20:49.396Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_jPsEa",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Lxr3u",
#       "createdAt": "2025-11-28T14:47:37.000Z",
#       "updatedAt": "2025-12-11T19:35:43.000Z",
#       "slug": "flux-2",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/f70c02e08b2006ba98d8044fc1ad556cd74fcf15/docs/api-references/autoDoc/flux-2.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:03:03.917Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_VjFIY",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/flux-2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/flux-2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_5LNjv",
#       "createdAt": "2025-12-11T18:15:40.000Z",
#       "updatedAt": "2025-12-11T18:15:40.000Z",
#       "slug": "model",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/8f7ba8f1d88af77bac6f5e6ff1d2023ef927d037/docs/api-references/autoDoc/model.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:11:58.633Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_gEa8H",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/model",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/model"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_NbaUy",
#       "createdAt": "2025-12-11T14:16:06.000Z",
#       "updatedAt": "2025-12-11T18:03:26.000Z",
#       "slug": "qwen-text-embedding-v4",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/e98d9d110bd72d516c0a5112b797195f14f6ef3b/docs/api-references/autoDoc/qwen-text-embedding-v4.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:02:37.364Z",
#       "lastProcessErrorCode": "PARSE_ERROR",
#       "lastProcessedErrors": [
#         {
#           "message": "Can’t find supported Swagger/OpenAPI version in the provided document, version must be a string."
#         }
#       ],
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v4",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v4"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_J7o1Z",
#       "createdAt": "2025-12-11T14:21:40.000Z",
#       "updatedAt": "2025-12-11T14:21:40.000Z",
#       "slug": "qwen-text-embedding-v4-and-v3",
#       "sourceURL": "https://raw.githubusercontent.com/D1m7asis/aimlapi-api-docs/816b36aa7dc411a62974b2e7f117fcc4b6b02339/docs/api-references/autoDoc/qwen-text-embedding-v4-and-v3.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T06:07:09.542Z",
#       "lastProcessErrorCode": "PARSE_ERROR",
#       "lastProcessedErrors": [
#         {
#           "message": "Can’t find supported Swagger/OpenAPI version in the provided document, version must be a string."
#         }
#       ],
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v4-and-v3",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v4-and-v3"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_zgbbI",
#       "createdAt": "2025-12-11T11:41:07.000Z",
#       "updatedAt": "2025-12-11T11:41:07.000Z",
#       "slug": "v5-5-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/PixVerse/v5.5-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:39:59.015Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_qJ3MJ",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v5-5-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v5-5-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_TemWH",
#       "createdAt": "2025-12-10T21:18:09.000Z",
#       "updatedAt": "2025-12-10T21:18:09.000Z",
#       "slug": "v5-5-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/PixVerse/v5.5-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T07:08:59.008Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_0cQY9",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/v5-5-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/v5-5-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_ofhVT",
#       "createdAt": "2025-04-22T20:49:04.000Z",
#       "updatedAt": "2025-12-10T17:20:37.000Z",
#       "slug": "kling-fetch",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2-master-image-to-video-pair.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:27:45.199Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_4SGAf",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-fetch",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-fetch"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_6MWgc",
#       "createdAt": "2025-04-25T13:57:25.000Z",
#       "updatedAt": "2025-12-10T16:02:30.000Z",
#       "slug": "kling-v2-master-i2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/v2-master-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T08:09:22.777Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_JbvAH",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-master-i2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-v2-master-i2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_p4gmF",
#       "createdAt": "2025-10-08T13:02:05.000Z",
#       "updatedAt": "2025-12-10T11:37:43.000Z",
#       "slug": "wan2-2-vace-fun-a14b-depth",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.2-vace-fun-a14b-depth.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:36:16.936Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_CL0cW",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-vace-fun-a14b-depth",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-vace-fun-a14b-depth"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_AIC6J",
#       "createdAt": "2025-10-08T11:59:36.000Z",
#       "updatedAt": "2025-12-10T11:12:24.000Z",
#       "slug": "wan2-2-14b-animate-move",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.2-14b-animate-move.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:23:20.990Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_6J1of",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-14b-animate-move",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-14b-animate-move"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_lFZnh",
#       "createdAt": "2025-08-04T07:38:43.000Z",
#       "updatedAt": "2025-12-10T11:06:27.000Z",
#       "slug": "wan2-2-t2v-plus",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.2-t2v-plus.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:21:19.787Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_l6k5D",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-t2v-plus",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan2-2-t2v-plus"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_NbTNy",
#       "createdAt": "2025-12-10T09:25:33.000Z",
#       "updatedAt": "2025-12-10T09:25:33.000Z",
#       "slug": "mythomax-l2-13b",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Gryphe/mythomax-l2-13b.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T07:19:32.824Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_WaeSN",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/mythomax-l2-13b",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/mythomax-l2-13b"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_lFPDh",
#       "createdAt": "2025-08-11T12:26:52.000Z",
#       "updatedAt": "2025-12-09T20:57:36.000Z",
#       "slug": "veo2-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/Veo2-Image-to-Video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T06:59:11.900Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_YGpiB",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo2-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo2-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_s3Uk2",
#       "createdAt": "2025-08-11T12:17:19.000Z",
#       "updatedAt": "2025-12-09T20:56:02.000Z",
#       "slug": "veo2",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Google/veo2.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T06:58:01.582Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_6psyj",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_lKKjh",
#       "createdAt": "2025-12-09T10:46:46.000Z",
#       "updatedAt": "2025-12-09T10:46:46.000Z",
#       "slug": "batch-cancel-2",
#       "sourceURL": "https://api.aimlapi.com/docs-public-yaml",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:06:25.094Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_2wT8p",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/batch-cancel-2",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/batch-cancel-2"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_2lRvk",
#       "createdAt": "2025-11-21T13:17:52.000Z",
#       "updatedAt": "2025-12-08T19:54:05.000Z",
#       "slug": "gemini-3-pro-image-preview-edit",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/image-models/Google/gemini-3-pro-image-preview-edit.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:17:16.359Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_FVebd",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gemini-3-pro-image-preview-edit",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gemini-3-pro-image-preview-edit"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_8e25P",
#       "createdAt": "2025-11-21T13:03:45.000Z",
#       "updatedAt": "2025-12-08T11:01:11.000Z",
#       "slug": "gemini-3-pro-image-preview",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/image-models/Google/gemini-3-pro-image-preview.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:17:14.809Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_o4Nzd",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gemini-3-pro-image-preview",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gemini-3-pro-image-preview"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_xiCgq",
#       "createdAt": "2025-12-07T22:22:46.000Z",
#       "updatedAt": "2025-12-07T22:22:46.000Z",
#       "slug": "video-v2-6-pro-image-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-v2-6-pro-image-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T08:33:49.134Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_2zWIt",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-v2-6-pro-image-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-v2-6-pro-image-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Lx0qu",
#       "createdAt": "2025-11-25T17:44:57.000Z",
#       "updatedAt": "2025-12-05T15:21:39.000Z",
#       "slug": "billing-test-1",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/service-endpoints/billing-balance.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T07:14:20.225Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1billing~1balance/get/requestBody",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_NFGqn",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/billing-test-1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/billing-test-1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_pLKTF",
#       "createdAt": "2025-11-14T15:13:01.000Z",
#       "updatedAt": "2025-12-05T11:54:18.000Z",
#       "slug": "gpt-5-1-codex-mini",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-mini-RESPONSES.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:53:44.691Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1responses/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_Q1IoE",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex-mini",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex-mini"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_VTLGS",
#       "createdAt": "2025-10-09T07:05:11.000Z",
#       "updatedAt": "2025-12-05T11:36:39.000Z",
#       "slug": "qwen3-omni-30b-a3b-captioner",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Alibaba-Cloud/qwen3-omni-30b-a3b-captioner.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:35:28.126Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_TnwmU",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/qwen3-omni-30b-a3b-captioner",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/qwen3-omni-30b-a3b-captioner"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_YshKx",
#       "createdAt": "2025-10-16T21:28:17.000Z",
#       "updatedAt": "2025-12-05T11:26:25.000Z",
#       "slug": "claude-haiku-4-5",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Anthropic/claude-haiku-4-5.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:31:07.057Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_pRg1A",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/claude-haiku-4-5",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/claude-haiku-4-5"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_LBktu",
#       "createdAt": "2025-10-16T21:07:04.000Z",
#       "updatedAt": "2025-12-05T11:23:11.000Z",
#       "slug": "anthropic-claude-sonnet-4-5",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Anthropic/claude-sonnet-4-5.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:29:28.771Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_Ebk0o",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/anthropic-claude-sonnet-4-5",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/anthropic-claude-sonnet-4-5"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Hfzl8",
#       "createdAt": "2025-06-13T11:05:32.000Z",
#       "updatedAt": "2025-12-05T11:19:02.000Z",
#       "slug": "claude-3-5-haiku",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Anthropic/claude-3-5-haiku.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:26:50.706Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_4QbOU",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/claude-3-5-haiku",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/claude-3-5-haiku"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_He3K8",
#       "createdAt": "2025-12-04T23:26:16.000Z",
#       "updatedAt": "2025-12-04T23:26:16.000Z",
#       "slug": "video-v2-6-pro-text-to-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-v2-6-pro-text-to-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T09:31:06.507Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_qGPjw",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-v2-6-pro-text-to-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-v2-6-pro-text-to-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_RQDTU",
#       "createdAt": "2025-10-08T06:21:57.000Z",
#       "updatedAt": "2025-12-04T21:20:25.000Z",
#       "slug": "glm-4-6",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Zhipu/glm-4.6.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T07:12:12.240Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_m3Yv6",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/glm-4-6",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/glm-4-6"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_VrLKS",
#       "createdAt": "2025-06-21T12:02:39.000Z",
#       "updatedAt": "2025-12-04T18:51:38.000Z",
#       "slug": "gpt-4-1",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-4.1.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T10:36:48.383Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_WMsJ1",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-4-1",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-4-1"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_w0Fun",
#       "createdAt": "2025-08-08T12:12:47.000Z",
#       "updatedAt": "2025-12-04T13:44:05.000Z",
#       "slug": "gpt-5-test",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:11:27.695Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_HOmmD",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-test",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-test"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_eZS0G",
#       "createdAt": "2025-08-07T08:19:28.000Z",
#       "updatedAt": "2025-12-04T13:42:14.000Z",
#       "slug": "gpt-oss-120b",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-oss-120b.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:10:38.265Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_0vHiG",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-oss-120b",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-oss-120b"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_RCJbU",
#       "createdAt": "2025-08-07T07:59:39.000Z",
#       "updatedAt": "2025-12-04T13:38:46.000Z",
#       "slug": "gpt-oss-20b",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-oss-20b.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:07:59.847Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_YDti6",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-oss-20b",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-oss-20b"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_DzDeK",
#       "createdAt": "2025-04-22T07:59:01.000Z",
#       "updatedAt": "2025-12-04T13:36:37.000Z",
#       "slug": "o4-mini",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/o4-mini.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2025-12-16T11:04:52.833Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_CKcPY",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/o4-mini",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/o4-mini"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_KWBjF",
# ...
#  ✓ Updated
# Updating: video-v2-6-pro-text-to-video
#  ✓ Updated
# Updating: glm-4-6
#  ✓ Updated
# Updating: gpt-4-1
#  ✓ Updated
# Updating: gpt-5-test
#  ✓ Updated
# Updating: gpt-oss-120b
#  ✓ Updated
# Updating: gpt-oss-20b
#  ✓ Updated
# Updating: o4-mini
#  ✓ Updated
# Updating: gpt-4-1-nano
#  ✓ Updated
# Updating: gpt-4-1-mini
#  ✓ Updated
# Updating: o3-pro-RESPONSES
#  ✓ Updated
# Updating: o3-mini
#  ✓ Updated
# Updating: o3
#  ✓ Updated
# Updating: o1
#  ✓ Updated
# Updating: gpt-4-preview
#  ✓ Updated
# Updating: gpt-4
#  ✓ Updated
# Updating: gpt-4-turbo
#  ✓ Updated
# Updating: gpt-4o-mini-search-preview
#  ✓ Updated
# Updating: gpt-4o-search-preview
#  ✓ Updated
# Updating: gpt-4o-mini-audio-preview
#  ✓ Updated
# Updating: gpt-4o-audio-preview
#  ✓ Updated
# Updating: gpt-4o
#  ✓ Updated
# Updating: gpt-4o-mini
#  ✓ Updated
# Updating: gpt-3-5-turbo
#  ✓ Updated
# Updating: z-image-turbo-lora
#  ✓ Updated
# Updating: z-image-turbo
#  ✓ Updated
# Updating: mistral-7b-instruct
#  ✓ Updated
# Updating: pixverse-v5-text-to-video
#  ✓ Updated
# Updating: qwen3-vl-32b-thinking
#  ✓ Updated
# Updating: qwen3-vl-32b-instruct
#  ✓ Updated
# Updating: flux-2-lora-edit
#  ✓ Updated
# Updating: flux-2-lora
#  ✓ Updated
# Updating: flux-2-edit
#  ✓ Updated
# Updating: flux-2-pro-edit
#  ✓ Updated
# Updating: flux-2-pro
#  ✓ Updated
# Updating: inworld-tts-1-max
#  ✓ Updated
# Updating: inworld-tts-1
#  ✓ Updated
# Updating: claude-opus-4-5
#  ✓ Updated
# Updating: qwen-turbo
#  ✓ Updated
# Updating: gpt-5-chat-RESPONSES
#  ✓ Updated
# Updating: gpt-5-mini-RESPONSES-v2
#  ✓ Updated
# Updating: o4-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-nano-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-RESPONSES
#  ✓ Updated
# Updating: o3-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4o-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-turbo-RESPONSES
#  ✓ Updated
# Updating: gpt-3-5-turbo-RESPONSES
#  ✓ Updated
# Updating: uso
#  ✓ Updated
# Updating: seedream-v4-edit
#  ✓ Updated
# Updating: seededit-3-0-i2i
#  ✓ Updated
# Updating: flux-kontext-pro-try-3
#  ✓ Updated
# Updating: flux-srpo-image-to-image
#  ✓ Updated
# Updating: sharpen-gen
#  ✓ Updated
# Updating: sharpen
#  ✓ Updated
# Updating: hunyuan-image-v3-text-to-image
#  ✓ Updated
# Updating: stable-diffusion-v35-large
#  ✓ Updated
# Updating: stable-diffusion-v3-medium
#  ✓ Updated
# Updating: reve-create-image
#  ✓ Updated
# Updating: recraft-v3
#  ✓ Updated
# Updating: gpt-image-1-gen
#  ✓ Updated
# Updating: dall-e-3
#  ✓ Updated
# Updating: dall-e-2
#  ✓ Updated
# Updating: gemini-2-5-flash-image
#  ✓ Updated
# Updating: imagen-4-0-ultra-generate-001
#  ✓ Updated
# Updating: imagen-4-0-fast-generate-001
#  ✓ Updated
# Updating: imagen-4-0-generate-001
#  ✓ Updated
# Updating: imagen-4-0-ultra
#  ✓ Updated
# Updating: imagen-4-preview
#  ✓ Updated
# Updating: imagen-3
#  ✓ Updated
# Updating: flux-srpo
#  ✓ Updated
# Updating: flux-kontext-pro-image-to-image
#  ✓ Updated
# Updating: flux-kontext-max-image-to-image
#  ✓ Updated
# Updating: flux-kontext-max
#  ✓ Updated
# Updating: flux-schnell
#  ✓ Updated
# Updating: flux-dev-image-to-image
#  ✓ Updated
# Updating: flux-dev
#  ✓ Updated
# Updating: flux-realism
#  ✓ Updated
# Updating: flux-pro-v1-1-ultra
#  ✓ Updated
# Updating: flux-pro-v1-1
#  ✓ Updated
# Updating: flux-pro
#  ✓ Updated
# Updating: seedream-v4-text-to-image
#  ✓ Updated
# Updating: bytedance-seedream-3-0
#  ✓ Updated
# Updating: qwen-image-edit
#  ✓ Updated
# Updating: qwen-image
#  ✓ Updated
# Updating: grok-4-1-fast-non-reasoning
#  ✓ Updated
# Updating: grok-4-1-fast-reasoning
#  ✓ Updated
# Updating: gpt-4-preview-RESPONSES
#  ✓ Updated
# Updating: gpt-4-RESPONSES
#  ✓ Updated
# Updating: gpt-4o-RESPONSES
#  ✓ Updated
# Updating: o3-RESPONSES
#  ✓ Updated
# Updating: o1-RESPONSES
#  ✓ Updated
# Updating: gpt-5-RESPONSES
#  ✓ Updated
# Updating: gpt-5-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-5-nano-RESPONSES
#  ✓ Updated
# Updating: gpt-5-1-RESPONSES
#  ✓ Updated
# Updating: gemini-2-5-flash-image-edit
#  ✓ Updated
# Updating: veo-3-1-i2v-fast
#  ✓ Updated
# Updating: veo-3-1-t2v-fast
#  ✓ Updated
# Updating: veo-3-1-reference-to-video
#  ✓ Updated
# Updating: veo-3-1-first-last-image-to-video
#  ✓ Updated
# Updating: veo-3-1-i2v
#  ✓ Updated
# Updating: gemini-3-pro-preview
#  ✓ Updated
# Updating: ltxv-2-fast
#  ✓ Updated
# Updating: fabric-1-0-fast
#  ✓ Updated
# Updating: fabric-1-0
#  ✓ Updated
# Updating: ltxv-2-test
#  ✓ Updated
# Updating: ltxv-2
#  ✓ Updated
# Updating: luma-v1-gen
#  ✓ Updated
# Updating: avatar-pro
#  ✓ Updated
# Updating: avatar-standard
#  ✓ Updated
# Updating: klingai-v2-1-master-image-to-video
#  ✓ Updated
# Updating: veo-3-1-first-last-image-to-video-fast
#  ✓ Updated
# Updating: seedance-1-0-lite-t2v
#  ✓ Updated
# Updating: wan-2-2-vace-fun-a14b-inpainting
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-outpainting
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-reframe
#  ✓ Updated
# Updating: alibaba-fetch
#  ✓ Updated
# Updating: bagoodex-search
#  ✓ Updated
# Updating: llama-3-3-70b-versatile
#  ✓ Updated
# Updating: meta-llama-3-1-405b-instruct-turbo
#  ✓ Updated
# Updating: meta-llama-3-1-70b-instruct-turbo
#  ✓ Updated
# Updating: gemini-2-0-flash-exp
#  ✓ Updated
# Updating: gpt-5-1-chat-latest-RESPONSES
#  ✓ Updated
# Updating: gpt-5-1-chat-latest
#  ✓ Updated
# Updating: grok-code-fast-1
#  ✓ Updated
# Updating: grok-3-beta
#  ✓ Updated
# Updating: sonar-pro
#  ✓ Updated
# Updating: sonar
#  ✓ Updated
# Updating: o1-mini
#  ✓ Updated
# Updating: hermes-4-405b
#  ✓ Updated
# Updating: m1
#  ✓ Updated
# Updating: deepseek-non-thinking-v3-2-exp
#  ✓ Updated
# Updating: deepseek-thinking-v3-2-exp
#  ✓ Updated
# Updating: deepseek-thinking-v3-2
#  ✓ Updated
# Updating: deepseek-chat-v3-1
#  ✓ Updated
# Updating: qwen-max
#  ✓ Updated
# Updating: qwen-plus
#  ✓ Updated
# Updating: sora-2-pro-i2v
#  ✓ Updated
# Updating: sora-2-pro-t2v
#  ✓ Updated
# Updating: sora-2-i2v
#  ✓ Updated
# Updating: sora-2-t2v-pair
#  ✓ Updated
# Updating: sora-2-t2v
#  ✓ Updated
# Updating: music-1-5
#  ✓ Updated
# Updating: speech-2-6-turbo
#  ✓ Updated
# Updating: speech-2-6-hd
#  ✓ Updated
# Updating: nemotron-nano-12b-v2-vl
#  ✓ Updated
# Updating: nemotron-nano-9b-v2
#  ✓ Updated
# Updating: omnihuman-v-1-5
#  ✓ Updated
# Updating: moonshot-kimi-k2-preview
#  ✓ Updated
# Updating: kimi-k2-turbo-preview
#  ✓ Updated
# Updating: m2
#  ✓ Updated
# Updating: aura-2
#  ✓ Updated
# Updating: ray-flash-2
#  ✓ Updated
# Updating: krea-wan-14b-video-to-video
#  ✓ Updated
# Updating: krea-wan-14b-text-to-video
#  ✓ Updated
# Updating: ray-2
#  ✓ Updated
# Updating: batch-cancel
#  ✓ Updated
# Updating: batch-get
#  ✓ Updated
# Updating: batch
#  ✓ Updated
# Updating: ray-1-6
#  ✓ Updated
# Updating: grok-2-image
#  ✓ Updated
# Updating: fetch-video-universal-endpoint
#  ✓ Updated
# Updating: kandinsky5-distill-t2v
#  ✓ Updated
# Updating: kandinsky5-t2v
#  ✓ Updated
# Updating: deepseek-non-reasoner-v3-1-terminus
#  ✓ Updated
# Updating: deepseek-reasoner-v3-1-terminus
#  ✓ Updated
# Updating: tts-1
#  ✓ Updated
# Updating: tts-1-hd
#  ✓ Updated
# Updating: gpt-4o-mini-tts
#  ✓ Updated
# Updating: fetch-video
#  ✓ Updated
# Updating: veo-3-1-t2v
#  ✓ Updated
# Updating: fabric-1-0-pair
#  ✓ Updated
# Updating: qwen3-tts-flash
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-pose
#  ✓ Updated
# Updating: wan2-2-14b-animate-replace
#  ✓ Updated
# Updating: claude-sonnet-4-5
#  ✗ Failed: ('Connection aborted.', ConnectionResetError(10054, 'Eine vorhandene Verbindung wurde vom Remotehost geschlossen', None, 10054, None))
# Updating: deepseek-non-thinking-v3-2
#  ✓ Updated
# Updating: reve-remix-edit-image
#  ✓ Updated
# Updating: reve-edit-image
#  ✓ Updated
# Updating: grok-4-fast-reasoning
#  ✓ Updated
# Updating: grok-4-fast-non-reasoning
#  ✓ Updated
# Updating: test-scalar-chatgpt-4o-latest
#  ✓ Updated
# Updating: qwen3-max-instruct
#  ✓ Updated
# Updating: omnihuman
#  ✓ Updated
# Updating: universal-video-endpoint-fetch
#  ✓ Updated
# Updating: qwen3-max-preview
#  ✓ Updated
# Updating: wan2-5-i2v-preview
#  ✓ Updated
# Updating: wan2-5-t2v-preview
#  ✓ Updated
# Updating: klingai-v1-6-standard-multi-image-to-video
#  ✓ Updated
# Updating: klingai-v2-5-turbo-pro-image-to-video
#  ✓ Updated
# Updating: v2-5-turbo-pro-text-to-video
#  ✓ Updated
# Updating: pixverse-v5-transition
#  ✓ Updated
# Updating: pixverse-v5-image-to-video
#  ✓ Updated
# Updating: pixverse-fetch
#  ✓ Updated
# Skipped: missing slug or sourceURL → oas_lGUbh
# Updating: v1-6-standart-image-to-video
#  ✓ Updated
# Updating: qwen3-next-80b-a3b-thinking
#  ✓ Updated
# Updating: qwen3-next-80b-a3b-instruct
#  ✓ Updated
# Updating: gemma-3n-e4b-it
#  ✓ Updated
# Updating: gpt-5-nano
#  ✓ Updated
# Updating: gpt-5-chat
#  ✓ Updated
# Updating: vibevoice-7b
#  ✓ Updated
# Updating: vibevoice-1-5b
#  ✓ Updated
# Updating: v3-alpha
#  ✓ Updated
# Updating: eleven-music-fetch
#  ✓ Updated
# Updating: eleven-music
#  ✓ Updated
# Updating: speech-2-5-turbo-preview
#  ✓ Updated
# Updating: speech-2-5-hd-preview
#  ✓ Updated
# Updating: deepseek-reasoner-v3-1
#  ✓ Updated
# Updating: kling-v2-1-pro-image-to-video
#  ✓ Updated
# Updating: kling-v2-1-standard-image-to-video
#  ✓ Updated
# Updating: minimax-music-fetch
#  ✓ Updated
# Updating: minimax-music
#  ✓ Updated
# Updating: response-api
#  ✓ Updated
# Updating: wan2-1-t2v-plus
#  ✓ Updated
# Updating: test-no-codesample-03
#  ✓ Updated
# Updating: test-no-codesample-02
#  ✓ Updated
# Updating: test-no-codesamples-01
#  ✓ Updated
# Updating: triposr-test-without-code-samles
#  ✓ Updated
# Updating: triposr
#  ✓ Updated
# Updating: m2-bert-80m-retrieval-v2
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video-v3
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video-v2
#  ✓ Updated
# Updating: aai-universal
#  ✓ Updated
# Updating: slam-1
#  ✓ Updated
# Updating: veo-3-0-fast
#  ✓ Updated
# Updating: veo-3-0-i2v-fast
#  ✓ Updated
# Updating: veo-3-0-i2v
#  ✓ Updated
# Updating: fetch-google-veos
#  ✓ Updated
# Updating: gpt-5-mini
#  ✓ Updated
# Updating: gpt-5
#  ✓ Updated
# Updating: runway-gen4-aleph
#  ✓ Updated
# Updating: runway-act-two
#  ✓ Updated
# Updating: claude-opus-4-1
#  ✓ Updated
# Updating: runway-gen4-turbo
#  ✓ Updated
# Updating: runway-gen3a-turbo
#  ✓ Updated
# Updating: runway-fetch
#  ✓ Updated
# Updating: ass-ass-create
#  ✓ Updated
# Updating: wan2-1-t2v-turbo
#  ✓ Updated
# Updating: wan2-2-i2v-plus
#  ✓ Updated
# Updating: horizon-beta
#  ✓ Updated
# Updating: horizon-alpha
#  ✓ Updated
# Updating: glm-4-5-air
#  ✓ Updated
# Updating: glm-4-5
#  ✓ Updated
# Updating: eleven-turbo-v2-5
#  ✓ Updated
# Updating: eleven-multilingual-v2
#  ✓ Updated
# Updating: qwen3-coder-480b-a35b-instruct
#  ✓ Updated
# Updating: qwen3-235b-a22b-thinking-2507
#  ✓ Updated
# Updating: qwen3-32b
#  ✓ Updated
# Updating: gemini-2-5-pro
#  ✓ Updated
# Updating: gemini-2-5-flash
#  ✓ Updated
# Updating: mistral-ocr-last
#  ✓ Updated
# Updating: mistral-ocr-latest
#  ✓ Updated
# Updating: google-ocr-last
#  ✓ Updated
# Updating: google-ocr-new
#  ✓ Updated
# Updating: google-ocr
#  ✓ Updated
# Updating: klingai-v2-1-master-text-to-video
#  ✓ Updated
# Updating: grok-4
#  ✓ Updated
# Updating: seedance-1-0-pro-text-to-video-after-repair
#  ✓ Updated
# Updating: test-20250721-06
#  ✓ Updated
# Updating: test-20250721-05
#  ✓ Updated
# Updating: test-20250721-04
#  ✓ Updated
# Updating: test-20250721-03
#  ✓ Updated
# Updating: test-202250721-02
#  ✓ Updated
# Updating: test-20250721
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video
#  ✓ Updated
# Updating: seedance-1-0-pro-text-to-video
#  ✓ Updated
# Updating: seedance-1-0-pro-t2v
#  ✓ Updated
# Updating: command-a
#  ✓ Updated
# Updating: gemini-2-5-flash-lite-preview
#  ✓ Updated
# Updating: responses-all-models
#  ✓ Updated
# Updating: o3-pro-response
#  ✓ Updated
# Updating: o3-pro-response-api
#  ✓ Updated
# Updating: seedance-1-0-lite-i2v
#  ✓ Updated
# Updating: bytedance-video-fetch
#  ✓ Updated
# Updating: m2-bert-80m-retrieval
#  ✓ Updated
# Updating: gemma-3
#  ✓ Updated
# Updating: nous-hermes-2
#  ✓ Updated
# Updating: grok-3-mini-beta
#  ✓ Updated
# Updating: grok-beta
#  ✓ Updated
# Updating: gpt-4-5-preview
#  ✓ Updated
# Updating: o1-preview
#  ✓ Updated
# Updating: hailuo-02
#  ✓ Updated
# Updating: gpt-image-1-edit
#  ✓ Updated
# Updating: nous-hermes-2-mixtral-8-7b-dpo
#  ✓ Updated
# Updating: nous-hermes-2-mixtral-8x7b-dpo
#  ✓ Updated
# Updating: llama-3-1-lumimaid
#  ✓ Updated
# Updating: llama-3-1-nemotron-70b
#  ✓ Updated
# Updating: llama-3-1-nemotron-70b-instruct-hf
#  ✓ Updated
# Updating: mixtral-8x7b-instruct
#  ✓ Updated
# Updating: mixtral-8x22b-instruct
#  ✓ Updated
# Updating: mistral-tiny
#  ✓ Updated
# Updating: mistral-nemo
#  ✓ Updated
# Updating: codestral-2501
#  ✓ Updated
# Updating: abab6-5s-chat
#  ✓ Updated
# Updating: text-01
#  ✓ Updated
# Updating: llama-4-maverick
#  ✓ Updated
# Updating: llama-4-scout
#  ✓ Updated
# Updating: llama-3-3-70b-instruct-turbo
#  ✓ Updated
# Updating: llama-3-2-3b-instruct-turbo
#  ✓ Updated
# Updating: llama-vision-free
#  ✓ Updated
# Updating: llama-3-2-90b-vision-instruct-turbo
#  ✓ Updated
# Updating: llama-3-2-11b-vision-instruct-turbo
#  ✓ Updated
# Updating: meta-llama-3-1-8b-instruct-turbo
#  ✓ Updated
# Updating: meta-llama-3-8b-instruct-lite
#  ✓ Updated
# Updating: llama-3-chat-h-f
#  ✓ Updated
# Updating: mythomax-l2-13b-lite
#  ✓ Updated
# Updating: gemini-2-5-pro-exp
#  ✓ Updated
# Updating: gemini-1-5-pro
#  ✓ Updated
# Updating: gemini-1-5-flash
#  ✓ Updated
# Updating: llama-3-chat-hf
#  ✓ Updated
# Updating: gemma-2-27b-it
#  ✓ Updated
# Updating: gemini-2-5-pro-preview
#  ✓ Updated
# Updating: gemini-2-0-flash
#  ✓ Updated
# Updating: deepseek-r1
#  ✓ Updated
# Updating: deepseek-chat-v3
#  ✓ Updated
# Updating: command-r-plus
#  ✓ Updated
# Updating: claude-4-opus
#  ✓ Updated
# Updating: claude-4-sonnet
#  ✓ Updated
# Updating: claude-3-7-sonnet
#  ✓ Updated
# Updating: claude-3-5-sonnet
#  ✓ Updated
# Updating: claude-3-sonnet
#  ✓ Updated
# Updating: claude-3-opus
#  ✓ Updated
# Updating: claude-3-haiku
#  ✓ Updated
# Updating: magnum-v4
#  ✓ Updated
# Updating: qwen-qwq-32b
#  ✓ Updated
# Updating: qwen2-5-coder-32b-instruct
#  ✓ Updated
# Updating: qwen2-5-7b-instruct-turbo
#  ✓ Updated
# Updating: qwen2-5-72b-instruct-turbo
#  ✓ Updated
# Updating: qwen2-72b-instruct-2nd-try
#  ✓ Updated
# Updating: qwen2-72b-instruct
#  ✓ Updated
# Updating: gpt-image-1
#  ✓ Updated
# Updating: local-gemini-2-5-flash-preview
#  ✓ Updated
# Updating: flux-kontext-pro-2025-06-11
#  ✓ Updated
# Updating: flux-kontext-pro
#  ✓ Updated
# Updating: veo3-fetch
#  ✓ Updated
# Updating: veo3
#  ✓ Updated
# Updating: test-constructor-2
#  ✓ Updated
# Updating: test-constructor
#  ✓ Updated
# Updating: anthropic-messages
#  ✓ Updated
# Updating: vision-ofr
#  ✓ Updated
# Updating: ass-runs-stepinfo
#  ✓ Updated
# Updating: ass-runs-steps-list
#  ✓ Updated
# Updating: ass-runs-cancel
#  ✓ Updated
# Updating: ass-runs-submit-tool-outputs
#  ✓ Updated
# Updating: ass-runs-runmodify
#  ✓ Updated
# Updating: ass-runs-runinfo
#  ✓ Updated
# Updating: ass-runs-get-list
#  ✓ Updated
# Updating: ass-runs-create-n-run
#  ✓ Updated
# Updating: ass-runs-create
#  ✓ Updated
# Updating: ass-msg-delete
#  ✓ Updated
# Updating: ass-msg-modify
#  ✓ Updated
# Updating: ass-msg-info
#  ✓ Updated
# Updating: ass-msg-list
#  ✓ Updated
# Updating: ass-msg-create
#  ✓ Updated
# Updating: stt-legacy
#  ✓ Updated
# Updating: models
#  ✓ Updated
# Updating: luma-v1-fetch
#  ✓ Updated
# Updating: luma-v2-extend
#  ✓ Updated
# Updating: luma-gens-fetch
#  ✓ Updated
# Updating: luma-gen-fetch
#  ✓ Updated
# Updating: ass-threads-delete
#  ✓ Updated
# Updating: ass-threads-modify
#  ✓ Updated
# Updating: ass-thread-info-id
#  ✓ Updated
# Updating: ass-threads-create
#  ✓ Updated
# Updating: ass-ass-delete
#  ✓ Updated
# Updating: ass-ass-modify
#  ✓ Updated
# Updating: ass-ass-info-id
#  ✓ Updated
# Updating: ass-ass-list
#  ✓ Updated
# Updating: bagoodex-knowledge
#  ✓ Updated
# Updating: bagoodex-map
#  ✓ Updated
# Updating: bagoodex-weather
#  ✓ Updated
# Updating: bagoodex-videos
#  ✓ Updated
# Updating: bagoodex-images
#  ✓ Updated
# Updating: gemma-3n
#  ✓ Updated
# Updating: bagoodex-links
#  ✓ Updated
# Updating: lyria2-fetch
#  ✓ Updated
# Updating: lyria2
#  ✓ Updated
# Updating: luma-t2v-v2
#  ✓ Updated
# Updating: whisper-tiny-2025-05-28
#  ✓ Updated
# Updating: whisper-small-2025-05-28
#  ✓ Updated
# Updating: whisper-medium-2025-05-28
#  ✓ Updated
# Updating: whisper-large-2025-05-28
#  ✓ Updated
# Updating: whisper-base-2025-05-28
#  ✓ Updated
# Updating: aura-2025-05-28
#  ✓ Updated
# Updating: stt-fetch
#  ✓ Updated
# Updating: nova-2
#  ✓ Updated
# Updating: grok-beta-test
#  ✓ Updated
# Updating: deepseek-prover-v2
#  ✓ Updated
# Updating: deepseek-prover-v2-wrong-place
#  ✓ Updated
# Updating: qwen3-wtf
#  ✓ Updated
# Updating: qwen3-235b
#  ✓ Updated
# Skipped: missing slug or sourceURL → oas_UcQoB
# Updating: kling-v2-master-t2v
#  ✓ Updated
# Updating: kling-v1-6-standard-effects
#  ✓ Updated
# Updating: kling-video-retrieve
#  ✓ Updated
# Updating: klingai-v1-6-pro-effects
#  ✓ Updated
# Updating: ai-ml-api-documentation-api
#  ✓ Updated
#
# ====== SUMMARY ======
# Total specs      : 444
# Updated          : 441
# Failed updates   : 1
# Skipped          : 2
# =====================

# %% [markdown]
# ## обновить прицельно одну апи-схему по её названию и URL

# %%
import requests
import time
import json

# —————————————————————————
# Настройки
TOKEN = "gb_api_vVVR78hJXh8dkcFDRtgn9LBHtFTQUmWAkQDdXe8q"
ORG_ID = "isNk5xPnJebTWJa4JCg5"

BASE_URL = "https://api.gitbook.com/v1"

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json",
    "Accept": "application/json",
}

# —————————————————————————
def list_openapi_specs():
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi?limit=1000"
    resp = requests.get(url, headers=HEADERS)
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    resp.raise_for_status()
    return resp.json().get("items", [])

def update_spec(spec_slug, source_url):
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi/{spec_slug}"
    body = {
        "source": {
            "url": source_url
        }
    }
    resp = requests.put(url, json=body, headers=HEADERS)
    resp.raise_for_status()
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    return resp.json()

def main():
    
    slug = "gpt-5-1-codex"
    source_url = "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-RESPONSES.json"
    print(f"Updating: {slug}")

    try:
        update_spec(slug, source_url)
        updated += 1
        print(f" ✓ Updated")
    except Exception as e:
        failed += 1
        print(f" ✗ Failed: {e}")

    # защита от rate-limit
    time.sleep(0.2)


if __name__ == "__main__":
    main()
# Out:
# Updating: gpt-5-1-codex
# {
#   "object": "openapi-spec",
#   "id": "oas_gT3IR",
#   "createdAt": "2025-11-14T15:07:27.000Z",
#   "updatedAt": "2025-12-16T11:31:34.000Z",
#   "slug": "gpt-5-1-codex",
#   "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-RESPONSES.json",
#   "processingState": "pending",
#   "visibility": "private",
#   "lastProcessedAt": "2025-12-16T11:28:57.146Z",
#   "lastProcessedErrors": [
#     {
#       "path": "/paths/~1v1~1responses/post/responses/200",
#       "message": "must have required property '$ref'"
#     }
#   ],
#   "lastVersion": "oasv_BGiGW",
#   "permissions": {
#     "view": true,
#     "edit": true
#   },
#   "urls": {
#     "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex",
#     "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex"
#   }
# }
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 48, in main()
#      47 update_spec(slug, source_url)
# ---> 48 updated += 1
#      49 print(f" ✓ Updated")
#
# UnboundLocalError: cannot access local variable 'updated' where it is not associated with a value
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 59
#      55     time.sleep(0.2)
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[9], line 51, in main()
#      49     print(f" ✓ Updated")
#      50 except Exception as e:
# ---> 51     failed += 1
#      52     print(f" ✗ Failed: {e}")
#      54 # защита от rate-limit
#
# UnboundLocalError: cannot access local variable 'failed' where it is not associated with a value
