# %% [markdown]
# ## найти все апи-схемы в нашей системе и принудительно обновить

# %%
import requests
import time
import json

# —————————————————————————
# Настройки
TOKEN = "gb_api_vVVR78hJXh8dkcFDRtgn9LBHtFTQUmWAkQDdXe8q"
ORG_ID = "isNk5xPnJebTWJa4JCg5"

BASE_URL = "https://api.gitbook.com/v1"

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json",
    "Accept": "application/json",
}

# —————————————————————————
def list_openapi_specs():
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi?limit=1000"
    resp = requests.get(url, headers=HEADERS)
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    resp.raise_for_status()
    return resp.json().get("items", [])

def update_spec(spec_slug, source_url):
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi/{spec_slug}"
    body = {
        "source": {
            "url": source_url
        }
    }
    resp = requests.put(url, json=body, headers=HEADERS)
    resp.raise_for_status()
    return resp.json()

def main():
    specs = list_openapi_specs()

    total = len(specs)
    updated = 0
    failed = 0
    skipped = 0

    print(f"Found {total} OpenAPI specs\n")

    for spec in specs:
        slug = spec.get("slug")
        source_url = spec.get("sourceURL")

        if not slug or not source_url:
            skipped += 1
            print(f"Skipped: missing slug or sourceURL → {spec.get('id', 'unknown')}")
            continue

        print(f"Updating: {slug}")

        try:
            update_spec(slug, source_url)
            updated += 1
            print(f" ✓ Updated")
        except Exception as e:
            failed += 1
            print(f" ✗ Failed: {e}")

        # защита от rate-limit
        time.sleep(0.2)

    # —————————————————————————
    print("\n====== SUMMARY ======")
    print(f"Total specs      : {total}")
    print(f"Updated          : {updated}")
    print(f"Failed updates   : {failed}")
    print(f"Skipped          : {skipped}")
    print("=====================")


if __name__ == "__main__":
    main()
# Out:
# {
#   "items": [
#     {
#       "object": "openapi-spec",
#       "id": "oas_SsGzC",
#       "createdAt": "2025-06-13T07:42:57.000Z",
#       "updatedAt": "2026-01-16T12:16:59.000Z",
#       "slug": "qwen2-5-7b-instruct-turbo",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/Alibaba-Cloud/Qwen2.5-7B-Instruct-Turbo.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T12:17:02.115Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1chat~1completions/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_QCwSY",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/qwen2-5-7b-instruct-turbo",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/qwen2-5-7b-instruct-turbo"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_GX9Id",
#       "createdAt": "2026-01-16T00:07:14.000Z",
#       "updatedAt": "2026-01-16T00:07:14.000Z",
#       "slug": "hunyuan-part",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/3d-generating-models/Tencent/hunyuan-part.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T12:07:18.629Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_yOTkn",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/hunyuan-part",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/hunyuan-part"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Lg9hu",
#       "createdAt": "2026-01-14T08:50:16.000Z",
#       "updatedAt": "2026-01-15T08:52:35.000Z",
#       "slug": "veo3-1-extend-video",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/Google/veo3-1-extend-video.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T08:52:39.391Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_sRDHx",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo3-1-extend-video",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo3-1-extend-video"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Rt1aU",
#       "createdAt": "2026-01-15T07:21:25.000Z",
#       "updatedAt": "2026-01-15T07:21:25.000Z",
#       "slug": "veo-3.1-t2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/Google/veo-3.1-t2v.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T07:21:34.310Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_oYxsy",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/veo-3.1-t2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/veo-3.1-t2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_RtIrU",
#       "createdAt": "2026-01-14T23:14:28.000Z",
#       "updatedAt": "2026-01-14T23:14:28.000Z",
#       "slug": "hunyuan-video-foley",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Tencent/hunyuan-video-foley.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T11:14:34.245Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_C6nxZ",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/hunyuan-video-foley",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/hunyuan-video-foley"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_NbaUy",
#       "createdAt": "2025-12-11T14:16:06.000Z",
#       "updatedAt": "2026-01-14T20:04:35.000Z",
#       "slug": "qwen-text-embedding-v4",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/embedding-models/alibaba-cloud/qwen-text-embedding-v4.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T08:05:06.270Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_vtVgM",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v4",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v4"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_lLCSh",
#       "createdAt": "2026-01-14T19:54:09.000Z",
#       "updatedAt": "2026-01-14T19:54:09.000Z",
#       "slug": "qwen-text-embedding-v3",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/embedding-models/alibaba-cloud/qwen-text-embedding-v3.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T07:54:32.322Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_G5kyX",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v3",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/qwen-text-embedding-v3"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas

#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/image-models/OpenAI/gpt-image-1-mini.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T11:46:45.162Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_Sxdut",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-image-1-mini",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-image-1-mini"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_q8cS6",
#       "createdAt": "2026-01-12T14:26:23.000Z",
#       "updatedAt": "2026-01-12T15:24:14.000Z",
#       "slug": "bytedance-seedance-1-0-pro-fast",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/bytedance/bytedance-seedance-1-0-pro-fast.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T09:24:23.491Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_xOtek",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/bytedance-seedance-1-0-pro-fast",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/bytedance-seedance-1-0-pro-fast"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_xHpbq",
#       "createdAt": "2026-01-12T11:43:09.000Z",
#       "updatedAt": "2026-01-12T11:43:09.000Z",
#       "slug": "gpt-4o-mini-transcribe",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/speech-models/OpenAI/gpt-4o-mini-transcribe.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T11:43:42.573Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_c9OdL",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-4o-mini-transcribe",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-4o-mini-transcribe"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_yihQY",
#       "createdAt": "2026-01-12T08:53:35.000Z",
#       "updatedAt": "2026-01-12T08:53:35.000Z",
#       "slug": "gpt-4o-transcribe",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/speech-models/OpenAI/gpt-4o-transcribe.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T08:53:57.903Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_wKU8Q",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-4o-transcribe",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-4o-transcribe"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_d7OrA",
#       "createdAt": "2026-01-08T22:51:21.000Z",
#       "updatedAt": "2026-01-08T22:51:21.000Z",
#       "slug": "video-v2-6-pro-motion-control",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Kling-AI/video-v2-6-pro-motion-control.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T11:03:18.177Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_udSiS",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/video-v2-6-pro-motion-control",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/video-v2-6-pro-motion-control"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_8tXfP",
#       "createdAt": "2025-06-18T08:56:28.000Z",
#       "updatedAt": "2026-01-08T20:41:28.000Z",
#       "slug": "gpt-image-1-edit",
#       "sourceURL": "https://api.aimlapi.com/docs-public-json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T08:41:58.864Z",
#       "lastProcessedErrors": [],
#       "lastVersion": "oasv_TsINK",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-image-1-edit",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-image-1-edit"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_HAey8",
#       "createdAt": "2026-01-08T17:40:48.000Z",
#       "updatedAt": "2026-01-08T18:11:44.000Z",
#       "slug": "kling-2-6-pro-motion-control",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/main/docs/api-references/video-models/kling-ai/kling-2-6-pro-motion-control.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T12:12:08.351Z",
#       "lastProcessErrorCode": "FETCH_ERROR",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_kg5x6",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/kling-2-6-pro-motion-control",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/kling-2-6-pro-motion-control"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_FWK3c",
#       "createdAt": "2026-01-07T23:31:16.000Z",
#       "updatedAt": "2026-01-07T23:31:16.000Z",
#       "slug": "music-2-0",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/music-models/MiniMax/music-2.0.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T11:37:57.641Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1generate~1audio/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_CyYBM",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/music-2-0",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/music-2-0"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_HA5O8",
#       "createdAt": "2026-01-07T13:05:18.000Z",
#       "updatedAt": "2026-01-07T21:24:30.000Z",
#       "slug": "wan-2-6-image",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/image-models/Alibaba-Cloud/wan-2-6-image.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T09:25:02.972Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v1~1images~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_o0n67",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan-2-6-image",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan-2-6-image"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_q8Vt6",
#       "createdAt": "2026-01-06T18:08:07.000Z",
#       "updatedAt": "2026-01-07T13:01:45.000Z",
#       "slug": "wan-2-6-r2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.6-r2v.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T13:02:29.084Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_5tUN3",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan-2-6-r2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/wan-2-6-r2v"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_YTUbx",
#       "createdAt": "2026-01-06T17:47:55.000Z",
#       "updatedAt": "2026-01-06T17:47:55.000Z",
#       "slug": "wan-2-6-t2v",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/Alibaba-Cloud/wan2.6-t2v.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T11:48:19.707Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_qw2Es",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/wan-2-6-t2v",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/w

#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_mzCtK",
#       "createdAt": "2025-08-06T09:03:29.000Z",
#       "updatedAt": "2025-12-24T13:43:39.000Z",
#       "slug": "runway-gen4-turbo",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/runway/gen4_turbo.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T07:44:33.862Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_gufWy",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/runway-gen4-turbo",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/runway-gen4-turbo"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_YReox",
#       "createdAt": "2025-08-07T10:26:55.000Z",
#       "updatedAt": "2025-12-24T13:38:58.000Z",
#       "slug": "runway-gen4-aleph",
#       "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/video-models/runway/gen4_aleph.json",
#       "processingState": "complete",
#       "visibility": "private",
#       "lastProcessedAt": "2026-01-16T07:39:44.154Z",
#       "lastProcessedErrors": [
#         {
#           "path": "/paths/~1v2~1video~1generations/post/responses/200",
#           "message": "must have required property '$ref'"
#         }
#       ],
#       "lastVersion": "oasv_o19OU",
#       "permissions": {
#         "view": true,
#         "edit": true
#       },
#       "urls": {
#         "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/runway-gen4-aleph",
#         "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/runway-gen4-aleph"
#       }
#     },
#     {
#       "object": "openapi-spec",
#       "id": "oas_Q8W83",
#       "createdAt": "2025-08-07T10:24:27.000Z",
#       "updatedAt": "2025-12-24T13:33:50.000Z",
#       "slug": "runway-act-two",
# ...
#  ✓ Updated
# Updating: gpt-4o
#  ✓ Updated
# Updating: gpt-4o-mini
#  ✓ Updated
# Updating: gpt-3-5-turbo
#  ✓ Updated
# Updating: z-image-turbo
#  ✓ Updated
# Updating: z-image-turbo-lora
#  ✓ Updated
# Updating: pixverse-v5-text-to-video
#  ✓ Updated
# Updating: mistral-7b-instruct
#  ✓ Updated
# Updating: qwen3-vl-32b-thinking
#  ✓ Updated
# Updating: qwen3-vl-32b-instruct
#  ✓ Updated
# Updating: flux-2-lora
#  ✓ Updated
# Updating: flux-2-lora-edit
#  ✓ Updated
# Updating: flux-2-edit
#  ✓ Updated
# Updating: flux-2-pro-edit
#  ✓ Updated
# Updating: flux-2-pro
#  ✓ Updated
# Updating: inworld-tts-1
#  ✓ Updated
# Updating: inworld-tts-1-max
#  ✓ Updated
# Updating: claude-opus-4-5
#  ✓ Updated
# Updating: qwen-turbo
#  ✓ Updated
# Updating: gpt-5-chat-RESPONSES
#  ✓ Updated
# Updating: gpt-5-mini-RESPONSES-v2
#  ✓ Updated
# Updating: o4-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-nano-RESPONSES
#  ✓ Updated
# Updating: gpt-4-1-RESPONSES
#  ✓ Updated
# Updating: gpt-4o-mini-RESPONSES
#  ✓ Updated
# Updating: o3-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-4-turbo-RESPONSES
#  ✓ Updated
# Updating: gpt-3-5-turbo-RESPONSES
#  ✓ Updated
# Updating: uso
#  ✓ Updated
# Updating: seedream-v4-edit
#  ✓ Updated
# Updating: flux-srpo-image-to-image
#  ✓ Updated
# Updating: seededit-3-0-i2i
#  ✓ Updated
# Updating: flux-kontext-pro-try-3
#  ✓ Updated
# Updating: sharpen
#  ✓ Updated
# Updating: sharpen-gen
#  ✓ Updated
# Updating: hunyuan-image-v3-text-to-image
#  ✓ Updated
# Updating: stable-diffusion-v3-medium
#  ✓ Updated
# Updating: stable-diffusion-v35-large
#  ✓ Updated
# Updating: reve-create-image
#  ✓ Updated
# Updating: gpt-image-1-gen
#  ✓ Updated
# Updating: recraft-v3
#  ✓ Updated
# Updating: dall-e-3
#  ✓ Updated
# Updating: dall-e-2
#  ✓ Updated
# Updating: gemini-2-5-flash-image
#  ✓ Updated
# Updating: imagen-4-0-ultra-generate-001
#  ✓ Updated
# Updating: imagen-4-0-fast-generate-001
#  ✓ Updated
# Updating: imagen-4-0-generate-001
#  ✓ Updated
# Updating: imagen-4-preview
#  ✗ Failed: 503 Server Error: Service Unavailable for url: https://api.gitbook.com/v1/orgs/isNk5xPnJebTWJa4JCg5/openapi/imagen-4-preview
# Updating: imagen-3
#  ✓ Updated
# Updating: imagen-4-0-ultra
#  ✓ Updated
# Updating: flux-srpo
#  ✓ Updated
# Updating: flux-kontext-max-image-to-image
#  ✓ Updated
# Updating: flux-kontext-pro-image-to-image
#  ✓ Updated
# Updating: flux-kontext-max
#  ✓ Updated
# Updating: flux-schnell
#  ✓ Updated
# Updating: flux-dev-image-to-image
#  ✓ Updated
# Updating: flux-dev
#  ✓ Updated
# Updating: flux-realism
#  ✓ Updated
# Updating: flux-pro-v1-1-ultra
#  ✓ Updated
# Updating: flux-pro-v1-1
#  ✓ Updated
# Updating: seedream-v4-text-to-image
#  ✓ Updated
# Updating: flux-pro
#  ✓ Updated
# Updating: bytedance-seedream-3-0
#  ✓ Updated
# Updating: qwen-image-edit
#  ✓ Updated
# Updating: qwen-image
#  ✓ Updated
# Updating: grok-4-1-fast-non-reasoning
#  ✓ Updated
# Updating: grok-4-1-fast-reasoning
#  ✓ Updated
# Updating: gpt-4-preview-RESPONSES
#  ✓ Updated
# Updating: gpt-4o-RESPONSES
#  ✓ Updated
# Updating: gpt-4-RESPONSES
#  ✓ Updated
# Updating: o3-RESPONSES
#  ✓ Updated
# Updating: o1-RESPONSES
#  ✓ Updated
# Updating: gpt-5-mini-RESPONSES
#  ✓ Updated
# Updating: gpt-5-RESPONSES
#  ✓ Updated
# Updating: gpt-5-nano-RESPONSES
#  ✓ Updated
# Updating: gemini-2-5-flash-image-edit
#  ✓ Updated
# Updating: gpt-5-1-RESPONSES
#  ✓ Updated
# Updating: veo-3-1-t2v-fast
#  ✓ Updated
# Updating: veo-3-1-i2v-fast
#  ✓ Updated
# Updating: veo-3-1-reference-to-video
#  ✓ Updated
# Updating: veo-3-1-i2v
#  ✓ Updated
# Updating: gemini-3-pro-preview
#  ✓ Updated
# Updating: veo-3-1-first-last-image-to-video
#  ✓ Updated
# Updating: ltxv-2-fast
#  ✓ Updated
# Updating: fabric-1-0
#  ✓ Updated
# Updating: fabric-1-0-fast
#  ✓ Updated
# Updating: ltxv-2-test
#  ✓ Updated
# Updating: ltxv-2
#  ✓ Updated
# Updating: luma-v1-gen
#  ✓ Updated
# Updating: avatar-pro
#  ✓ Updated
# Updating: avatar-standard
#  ✓ Updated
# Updating: veo-3-1-first-last-image-to-video-fast
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-outpainting
#  ✓ Updated
# Updating: wan-2-2-vace-fun-a14b-inpainting
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-reframe
#  ✓ Updated
# Updating: alibaba-fetch
#  ✓ Updated
# Updating: bagoodex-search
#  ✓ Updated
# Updating: meta-llama-3-1-405b-instruct-turbo
#  ✓ Updated
# Updating: llama-3-3-70b-versatile
#  ✓ Updated
# Updating: meta-llama-3-1-70b-instruct-turbo
#  ✓ Updated
# Updating: gemini-2-0-flash-exp
#  ✓ Updated
# Updating: gpt-5-1-chat-latest-RESPONSES
#  ✓ Updated
# Updating: gpt-5-1-chat-latest
#  ✓ Updated
# Updating: grok-3-beta
#  ✓ Updated
# Updating: grok-code-fast-1
#  ✓ Updated
# Updating: sonar-pro
#  ✓ Updated
# Updating: o1-mini
#  ✓ Updated
# Updating: sonar
#  ✓ Updated
# Updating: m1
#  ✓ Updated
# Updating: deepseek-non-thinking-v3-2-exp
#  ✓ Updated
# Updating: hermes-4-405b
#  ✓ Updated
# Updating: deepseek-thinking-v3-2-exp
#  ✓ Updated
# Updating: deepseek-chat-v3-1
#  ✓ Updated
# Updating: deepseek-thinking-v3-2
#  ✓ Updated
# Updating: qwen-plus
#  ✓ Updated
# Updating: qwen-max
#  ✓ Updated
# Updating: sora-2-pro-i2v
#  ✓ Updated
# Updating: sora-2-pro-t2v
#  ✓ Updated
# Updating: sora-2-i2v
#  ✓ Updated
# Updating: sora-2-t2v-pair
#  ✓ Updated
# Updating: sora-2-t2v
#  ✓ Updated
# Updating: speech-2-6-turbo
#  ✓ Updated
# Updating: speech-2-6-hd
#  ✓ Updated
# Updating: nemotron-nano-9b-v2
#  ✓ Updated
# Updating: nemotron-nano-12b-v2-vl
#  ✓ Updated
# Updating: omnihuman-v-1-5
#  ✓ Updated
# Updating: moonshot-kimi-k2-preview
#  ✓ Updated
# Updating: m2
#  ✓ Updated
# Updating: aura-2
#  ✓ Updated
# Updating: kimi-k2-turbo-preview
#  ✓ Updated
# Updating: ray-flash-2
#  ✓ Updated
# Updating: krea-wan-14b-text-to-video
#  ✓ Updated
# Updating: krea-wan-14b-video-to-video
#  ✓ Updated
# Updating: ray-2
#  ✓ Updated
# Updating: batch-cancel
#  ✓ Updated
# Updating: batch-get
#  ✓ Updated
# Updating: ray-1-6
#  ✓ Updated
# Updating: batch
#  ✓ Updated
# Updating: grok-2-image
#  ✓ Updated
# Updating: kandinsky5-distill-t2v
#  ✓ Updated
# Updating: fetch-video-universal-endpoint
#  ✓ Updated
# Updating: deepseek-reasoner-v3-1-terminus
#  ✓ Updated
# Updating: kandinsky5-t2v
#  ✓ Updated
# Updating: deepseek-non-reasoner-v3-1-terminus
#  ✓ Updated
# Updating: tts-1
#  ✓ Updated
# Updating: gpt-4o-mini-tts
#  ✓ Updated
# Updating: tts-1-hd
#  ✓ Updated
# Updating: fetch-video
#  ✓ Updated
# Updating: qwen3-tts-flash
#  ✓ Updated
# Updating: veo-3-1-t2v
#  ✓ Updated
# Updating: fabric-1-0-pair
#  ✓ Updated
# Updating: wan2-2-vace-fun-a14b-pose
#  ✓ Updated
# Updating: reve-remix-edit-image
#  ✓ Updated
# Updating: wan2-2-14b-animate-replace
#  ✓ Updated
# Updating: deepseek-non-thinking-v3-2
#  ✓ Updated
# Updating: reve-edit-image
#  ✓ Updated
# Updating: grok-4-fast-reasoning
#  ✓ Updated
# Updating: grok-4-fast-non-reasoning
#  ✓ Updated
# Updating: qwen3-max-instruct
#  ✓ Updated
# Updating: test-scalar-chatgpt-4o-latest
#  ✓ Updated
# Updating: omnihuman
#  ✓ Updated
# Updating: qwen3-max-preview
#  ✓ Updated
# Updating: wan2-5-i2v-preview
#  ✓ Updated
# Updating: wan2-5-t2v-preview
#  ✓ Updated
# Updating: klingai-v1-6-standard-multi-image-to-video
#  ✓ Updated
# Updating: v1-6-standart-image-to-video
#  ✓ Updated
# Updating: pixverse-fetch
#  ✓ Updated
# Updating: qwen3-next-80b-a3b-instruct
#  ✓ Updated
# Updating: qwen3-next-80b-a3b-thinking
#  ✓ Updated
# Updating: gemma-3n-e4b-it
#  ✓ Updated
# Updating: gpt-5-chat
#  ✓ Updated
# Updating: gpt-5-nano
#  ✓ Updated
# Updating: vibevoice-7b
#  ✓ Updated
# Updating: v3-alpha
#  ✓ Updated
# Updating: vibevoice-1-5b
#  ✓ Updated
# Updating: speech-2-5-turbo-preview
#  ✓ Updated
# Updating: speech-2-5-hd-preview
#  ✓ Updated
# Updating: deepseek-reasoner-v3-1
#  ✓ Updated
# Updating: minimax-music-fetch
#  ✓ Updated
# Updating: minimax-music
#  ✓ Updated
# Updating: response-api
#  ✓ Updated
# Updating: test-no-codesample-03
#  ✓ Updated
# Updating: test-no-codesamples-01
#  ✓ Updated
# Updating: test-no-codesample-02
#  ✓ Updated
# Updating: triposr-test-without-code-samles
#  ✓ Updated
# Updating: triposr
#  ✓ Updated
# Updating: m2-bert-80m-retrieval-v2
#  ✓ Updated
# Updating: aai-universal
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video-v2
#  ✓ Updated
# Updating: gpt-5-mini
#  ✓ Updated
# Updating: slam-1
#  ✓ Updated
# Updating: fetch-google-veos
#  ✓ Updated
# Updating: gpt-5
#  ✓ Updated
# Updating: claude-opus-4-1
#  ✓ Updated
# Updating: ass-ass-create
#  ✓ Updated
# Updating: runway-fetch
#  ✓ Updated
# Updating: wan2-2-i2v-plus
#  ✓ Updated
# Updating: horizon-alpha
#  ✓ Updated
# Updating: horizon-beta
#  ✓ Updated
# Updating: glm-4-5-air
#  ✓ Updated
# Updating: eleven-turbo-v2-5
#  ✓ Updated
# Updating: glm-4-5
#  ✓ Updated
# Updating: qwen3-coder-480b-a35b-instruct
#  ✓ Updated
# Updating: eleven-multilingual-v2
#  ✓ Updated
# Updating: qwen3-235b-a22b-thinking-2507
#  ✓ Updated
# Updating: qwen3-32b
#  ✓ Updated
# Updating: gemini-2-5-pro
#  ✓ Updated
# Updating: mistral-ocr-last
#  ✓ Updated
# Updating: gemini-2-5-flash
#  ✓ Updated
# Updating: mistral-ocr-latest
#  ✓ Updated
# Updating: google-ocr-new
#  ✓ Updated
# Updating: google-ocr
#  ✓ Updated
# Updating: google-ocr-last
#  ✓ Updated
# Updating: grok-4
#  ✓ Updated
# Updating: test-20250721-06
#  ✓ Updated
# Updating: test-20250721-04
#  ✓ Updated
# Updating: test-20250721-05
#  ✓ Updated
# Updating: test-20250721-03
#  ✓ Updated
# Updating: test-202250721-02
#  ✓ Updated
# Updating: test-20250721
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video
#  ✓ Updated
# Updating: seedance-1-0-pro-t2v
#  ✓ Updated
# Updating: seedance-1-0-pro-text-to-video
#  ✓ Updated
# Updating: command-a
#  ✓ Updated
# Updating: responses-all-models
#  ✓ Updated
# Updating: gemini-2-5-flash-lite-preview
#  ✓ Updated
# Updating: o3-pro-response
#  ✓ Updated
# Updating: o3-pro-response-api
#  ✓ Updated
# Updating: bytedance-video-fetch
#  ✓ Updated
# Updating: m2-bert-80m-retrieval
#  ✓ Updated
# Updating: nous-hermes-2
#  ✓ Updated
# Updating: grok-3-mini-beta
#  ✓ Updated
# Updating: grok-beta
#  ✓ Updated
# Updating: o1-preview
#  ✓ Updated
# Updating: gpt-4-5-preview
#  ✓ Updated
# Updating: nous-hermes-2-mixtral-8-7b-dpo
#  ✓ Updated
# Updating: llama-3-1-lumimaid
#  ✓ Updated
# Updating: nous-hermes-2-mixtral-8x7b-dpo
#  ✓ Updated
# Updating: llama-3-1-nemotron-70b-instruct-hf
#  ✓ Updated
# Updating: llama-3-1-nemotron-70b
#  ✓ Updated
# Updating: mixtral-8x7b-instruct
#  ✓ Updated
# Updating: mistral-tiny
#  ✓ Updated
# Updating: mixtral-8x22b-instruct
#  ✓ Updated
# Updating: mistral-nemo
#  ✓ Updated
# Updating: abab6-5s-chat
#  ✓ Updated
# Updating: codestral-2501
#  ✓ Updated
# Updating: text-01
#  ✓ Updated
# Updating: llama-4-maverick
#  ✓ Updated
# Updating: llama-4-scout
#  ✓ Updated
# Updating: llama-3-3-70b-instruct-turbo
#  ✓ Updated
# Updating: llama-3-2-3b-instruct-turbo
#  ✓ Updated
# Updating: llama-vision-free
#  ✓ Updated
# Updating: llama-3-2-90b-vision-instruct-turbo
#  ✓ Updated
# Updating: llama-3-2-11b-vision-instruct-turbo
#  ✓ Updated
# Updating: meta-llama-3-1-8b-instruct-turbo
#  ✓ Updated
# Updating: meta-llama-3-8b-instruct-lite
#  ✓ Updated
# Updating: llama-3-chat-h-f
#  ✓ Updated
# Updating: mythomax-l2-13b-lite
#  ✓ Updated
# Updating: gemini-2-5-pro-exp
#  ✓ Updated
# Updating: gemini-1-5-flash
#  ✓ Updated
# Updating: gemini-1-5-pro
#  ✓ Updated
# Updating: llama-3-chat-hf
#  ✓ Updated
# Updating: gemini-2-5-pro-preview
#  ✓ Updated
# Updating: gemma-2-27b-it
#  ✓ Updated
# Updating: gemini-2-0-flash
#  ✓ Updated
# Updating: deepseek-chat-v3
#  ✓ Updated
# Updating: deepseek-r1
#  ✓ Updated
# Updating: command-r-plus
#  ✓ Updated
# Updating: claude-4-opus
#  ✓ Updated
# Updating: claude-3-7-sonnet
#  ✓ Updated
# Updating: claude-4-sonnet
#  ✓ Updated
# Updating: claude-3-5-sonnet
#  ✓ Updated
# Updating: claude-3-opus
#  ✓ Updated
# Updating: claude-3-sonnet
#  ✓ Updated
# Updating: claude-3-haiku
#  ✓ Updated
# Updating: magnum-v4
#  ✓ Updated
# Updating: qwen2-5-coder-32b-instruct
#  ✓ Updated
# Updating: qwen-qwq-32b
#  ✓ Updated
# Updating: qwen2-72b-instruct-2nd-try
#  ✓ Updated
# Updating: qwen2-5-72b-instruct-turbo
#  ✓ Updated
# Updating: local-gemini-2-5-flash-preview
#  ✓ Updated
# Updating: qwen2-72b-instruct
#  ✓ Updated
# Updating: gpt-image-1
#  ✓ Updated
# Updating: flux-kontext-pro
#  ✓ Updated
# Updating: flux-kontext-pro-2025-06-11
#  ✓ Updated
# Updating: veo3-fetch
#  ✓ Updated
# Updating: test-constructor
#  ✓ Updated
# Updating: test-constructor-2
#  ✓ Updated
# Updating: anthropic-messages
#  ✓ Updated
# Updating: vision-ofr
#  ✓ Updated
# Updating: ass-runs-stepinfo
#  ✓ Updated
# Updating: ass-runs-steps-list
#  ✓ Updated
# Updating: ass-runs-cancel
#  ✓ Updated
# Updating: ass-runs-runmodify
#  ✓ Updated
# Updating: ass-runs-submit-tool-outputs
#  ✓ Updated
# Updating: ass-runs-get-list
#  ✓ Updated
# Updating: ass-runs-runinfo
#  ✓ Updated
# Updating: ass-runs-create-n-run
#  ✓ Updated
# Updating: ass-msg-delete
#  ✓ Updated
# Updating: ass-runs-create
#  ✓ Updated
# Updating: ass-msg-modify
#  ✓ Updated
# Updating: ass-msg-info
#  ✓ Updated
# Updating: ass-msg-list
#  ✓ Updated
# Updating: stt-legacy
#  ✓ Updated
# Updating: ass-msg-create
#  ✓ Updated
# Updating: models
#  ✓ Updated
# Updating: luma-v2-extend
#  ✓ Updated
# Updating: luma-gens-fetch
#  ✓ Updated
# Updating: luma-v1-fetch
#  ✓ Updated
# Updating: luma-gen-fetch
#  ✓ Updated
# Updating: ass-threads-delete
#  ✓ Updated
# Updating: ass-threads-modify
#  ✓ Updated
# Updating: ass-threads-create
#  ✓ Updated
# Updating: ass-ass-delete
#  ✓ Updated
# Updating: ass-thread-info-id
#  ✓ Updated
# Updating: ass-ass-modify
#  ✓ Updated
# Updating: ass-ass-info-id
#  ✓ Updated
# Updating: ass-ass-list
#  ✓ Updated
# Updating: bagoodex-knowledge
#  ✓ Updated
# Updating: bagoodex-map
#  ✓ Updated
# Updating: bagoodex-weather
#  ✓ Updated
# Updating: bagoodex-videos
#  ✓ Updated
# Updating: bagoodex-images
#  ✓ Updated
# Updating: gemma-3n
#  ✓ Updated
# Updating: lyria2-fetch
#  ✓ Updated
# Updating: bagoodex-links
#  ✓ Updated
# Updating: luma-t2v-v2
#  ✓ Updated
# Updating: whisper-tiny-2025-05-28
#  ✓ Updated
# Updating: whisper-medium-2025-05-28
#  ✓ Updated
# Updating: whisper-small-2025-05-28
#  ✓ Updated
# Updating: whisper-large-2025-05-28
#  ✓ Updated
# Updating: aura-2025-05-28
#  ✓ Updated
# Updating: whisper-base-2025-05-28
#  ✓ Updated
# Updating: stt-fetch
#  ✓ Updated
# Updating: nova-2
#  ✓ Updated
# Updating: deepseek-prover-v2
#  ✓ Updated
# Updating: grok-beta-test
#  ✓ Updated
# Updating: deepseek-prover-v2-wrong-place
#  ✓ Updated
# Updating: qwen3-wtf
#  ✓ Updated
# Updating: qwen3-235b
#  ✓ Updated
# Updating: kling-video-retrieve
#  ✓ Updated
# Updating: ai-ml-api-documentation-api
#  ✓ Updated
# Updating: gpt-image-1-5
#  ✓ Updated
# Updating: seedance-1-0-pro-fast
#  ✓ Updated
# Updating: flux-2-max
#  ✓ Updated
# Updating: gemini-3-flash-preview
#  ✓ Updated
# Updating: gpt-5-1
#  ✓ Updated
# Updating: v1-standard-image-to-video
#  ✓ Updated
# Updating: v5-5-text-to-video
#  ✓ Updated
# Updating: v1-pro-text-to-video
#  ✓ Updated
# Updating: v1-6-standard-text-to-video
#  ✓ Updated
# Updating: v1-pro-image-to-video
#  ✓ Updated
# Updating: v1-6-standard-image-to-video
#  ✓ Updated
# Updating: v1-6-pro-image-to-video
#  ✓ Updated
# Updating: v1-6-pro-text-to-video
#  ✓ Updated
# Updating: v1-6-pro-image-to-video-2
#  ✓ Updated
# Updating: kling-v1-6-standard-effects
#  ✓ Updated
# Updating: kling-v2-master-t2v
#  ✓ Updated
# Updating: klingai-v1-6-pro-effects
#  ✓ Updated
# Updating: kling-v2-master-i2v
#  ✓ Updated
# Updating: kling-v2-1-pro-image-to-video
#  ✓ Updated
# Updating: kling-v2-1-standard-image-to-video
#  ✓ Updated
# Updating: klingai-v2-1-master-text-to-video
#  ✓ Updated
# Updating: klingai-v2-1-master-image-to-video
#  ✓ Updated
# Updating: v2-5-turbo-pro-text-to-video
#  ✓ Updated
# Updating: klingai-v2-5-turbo-pro-image-to-video
#  ✓ Updated
# Updating: v1-6-standard-multi-image-to-video
#  ✓ Updated
# Updating: wan2-1-t2v-plus
#  ✓ Updated
# Updating: wan2-1-t2v-turbo
#  ✓ Updated
# Updating: wan2-2-t2v-plus
#  ✓ Updated
# Updating: wan2-5-t2v-preview-2
#  ✓ Updated
# Updating: wan2-5-i2v-preview-2
#  ✓ Updated
# Updating: image-o1
#  ✓ Updated
# Updating: video-o1-image-to-video
#  ✓ Updated
# Updating: kling-video-o1-video-to-video-edit
#  ✓ Updated
# Updating: kling-video-o1-video-to-video-reference
#  ✓ Updated
# Updating: seedance-1-0-lite-i2v
#  ✓ Updated
# Updating: seedance-1-0-lite-t2v
#  ✓ Updated
# Updating: seedance-1-0-pro-text-to-video-after-repair
#  ✓ Updated
# Updating: seedance-1-0-pro-image-to-video-v3
#  ✓ Updated
# Updating: veo2
#  ✓ Updated
# Updating: veo2-image-to-video
#  ✓ Updated
# Updating: veo3
#  ✓ Updated
# Updating: veo-3-0-fast
#  ✓ Updated
# Updating: veo-3-0-i2v
#  ✓ Updated
# Updating: veo-3-0-i2v-fast
#  ✓ Updated
# Updating: hailuo-02
#  ✓ Updated
# Updating: video-01-live2d
#  ✓ Updated
# Updating: video-01
#  ✓ Updated
# Updating: glm-4-7
#  ✓ Updated
# Updating: video-o1-reference-to-video
#  ✓ Updated
# Updating: minimax-m2-1
#  ✓ Updated
# Updating: m2-1
#  ✓ Updated
# Skipped: missing slug or sourceURL → oas_lGUbh
# Skipped: missing slug or sourceURL → oas_UcQoB
#
# ====== SUMMARY ======
# Total specs      : 506
# Updated          : 502
# Failed updates   : 1
# Skipped          : 3
# =====================

# %% [markdown]
# ## обновить прицельно одну апи-схему по её названию и URL

# %%
import requests
import time
import json

# —————————————————————————
# Настройки
TOKEN = "gb_api_vVVR78hJXh8dkcFDRtgn9LBHtFTQUmWAkQDdXe8q"
ORG_ID = "isNk5xPnJebTWJa4JCg5"

BASE_URL = "https://api.gitbook.com/v1"

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json",
    "Accept": "application/json",
}

# —————————————————————————
def list_openapi_specs():
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi?limit=1000"
    resp = requests.get(url, headers=HEADERS)
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    resp.raise_for_status()
    return resp.json().get("items", [])

def update_spec(spec_slug, source_url):
    url = f"{BASE_URL}/orgs/{ORG_ID}/openapi/{spec_slug}"
    body = {
        "source": {
            "url": source_url
        }
    }
    resp = requests.put(url, json=body, headers=HEADERS)
    resp.raise_for_status()
    data = resp.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
    return resp.json()

def main():
    
    slug = "gpt-5-1-codex"
    source_url = "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-RESPONSES.json"
    print(f"Updating: {slug}")

    try:
        update_spec(slug, source_url)
        updated += 1
        print(f" ✓ Updated")
    except Exception as e:
        failed += 1
        print(f" ✗ Failed: {e}")

    # защита от rate-limit
    time.sleep(0.2)


if __name__ == "__main__":
    main()
# Out:
# Updating: gpt-5-1-codex
# {
#   "object": "openapi-spec",
#   "id": "oas_gT3IR",
#   "createdAt": "2025-11-14T15:07:27.000Z",
#   "updatedAt": "2025-12-16T11:31:34.000Z",
#   "slug": "gpt-5-1-codex",
#   "sourceURL": "https://raw.githubusercontent.com/aimlapi/api-docs/refs/heads/main/docs/api-references/text-models-llm/OpenAI/gpt-5-1-codex-RESPONSES.json",
#   "processingState": "pending",
#   "visibility": "private",
#   "lastProcessedAt": "2025-12-16T11:28:57.146Z",
#   "lastProcessedErrors": [
#     {
#       "path": "/paths/~1v1~1responses/post/responses/200",
#       "message": "must have required property '$ref'"
#     }
#   ],
#   "lastVersion": "oasv_BGiGW",
#   "permissions": {
#     "view": true,
#     "edit": true
#   },
#   "urls": {
#     "app": "https://app.gitbook.com/o/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex",
#     "location": "/orgs/isNk5xPnJebTWJa4JCg5/openapi/gpt-5-1-codex"
#   }
# }
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 48, in main()
#      47 update_spec(slug, source_url)
# ---> 48 updated += 1
#      49 print(f" ✓ Updated")
#
# UnboundLocalError: cannot access local variable 'updated' where it is not associated with a value
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 59
#      55     time.sleep(0.2)
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[9], line 51, in main()
#      49     print(f" ✓ Updated")
#      50 except Exception as e:
# ---> 51     failed += 1
#      52     print(f" ✗ Failed: {e}")
#      54 # защита от rate-limit
#
# UnboundLocalError: cannot access local variable 'failed' where it is not associated with a value
